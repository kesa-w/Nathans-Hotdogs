# %%
#Website with Contest winners 

#https://www.lastsandwich.com/articles/sandwich-sports/all-time-list-of-nathan-s-hot-dog-eating-champions

# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd
import numpy

# %%
#Get the info from website
hotdog_url = ("https://www.lastsandwich.com/articles/sandwich-sports/all-time-list-of-nathan-s-hot-dog-eating-champions")
hotdog_url = requests.get(hotdog_url)

# %%
#Gets the text from a website
hotdog_url = hotdog_url.text
print(hotdog_url) #Provides the text of the website
# Out:
# <!DOCTYPE html>
# <html prefix="og: http://ogp.me/ns#" lang="en-GB" dir="ltr">
#         <head>
#
#             <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#
#
#
#
#          <meta charset="utf-8" />
# 	<base href="https://www.lastsandwich.com/articles/sandwich-sports/all-time-list-of-nathan-s-hot-dog-eating-champions" />
# 	<meta name="keywords" content="hotdog winners, nathan hotdog winners, nathans hotdog winners, hotdog champions, nathan hotdog champions, nathans hotdog champions, hotdog list, nathan hotdog list, nathans hotdog list, nathan winners, nathans winners, nathan list, nathans list, hotdog eating winner, hotdog eating winners, hotdog eating champion, hotdog eating champions, nathans all time winners, nathans all time champions, hotdog all time winners, hotdog all time champions, nathans chart, nathan chart, nathans top winners, nathan top champions, top hotdog winners, top hotdog champions, joey chestnut, miki sudo, hot dog eating winners, hot dog eating champions, hot dog winners, hot dog champions, hot dog world record, hotdog world record, hot dog eating world record, hotdog eating world record" />
# 	<meta name="rights" content="TERMS AND CONDITIONS OF USE
# Effective Date: June 2010
# This website, including any subsite accessible through the homepage (the &quot;Site&quot;), is published and maintained by subsidiaries, affiliates, and/or related entities of Last Sandwich LLC (&quot;Last Sandwich&quot;). Please note that when you enter any subsite accessible through this homepage or the shopping page, such subsite may have its own terms and conditions of use which are specific to such subsite. When you access, browse, or use this Site you accept, without limitation or qualification, the terms and conditions set forth below and any additional terms and conditions of use set forth in any subsite.
# Your Right to Use the Site and Its Contents
# This Site is only for your personal use. You may not distribute, exchange, modify, sell, or transmit anything you copy from this Site, including but not limited to any text, images, audio, and video, for any business, commercial, or public purpose. As long as you comply with the terms of these Terms and Conditions of Use, Last Sandwich grants you a non-exclusive, non- transferable, limited right to enter, display, and use this Site. You agree not to interrupt or attempt to interrupt the operation of this Site in any way.
# Ownership
# All materials on this Site, including but not limited to audio, images, software, text, and video clips (the &quot;Content&quot;), are protected by copyright under U.S. copyright law, international conventions, and other copyright laws. You cannot use the Content, except as specified herein. You agree to follow all instructions on this Site limiting the way you may use the Content. There are a number of proprietary logos, service marks, and trademarks found on this Site. By making them available on this Site, Last Sandwich is not granting you any license to utilize those proprietary logos, service marks, or trademarks. Any unauthorized use of the Content may violate copyright laws, trademark laws, the laws of privacy and publicity, and civil and criminal statutes.
# You may download one (1) copy only of the Content to be used only by you for your personal use at home, unless the subsite you are accessing states that you may not. If you download any Content from this Site, you may not remove any copyright or trademark notices or other notices that go with it.
# Rules for Chatrooms, Bulletin Boards, and Other User-Supplied Material
# This website may have an area which allows you to &quot;chat&quot; or upload and download materials. When using any of these areas, you agree not to post, send, transmit, upload, or otherwise publish through this Site, any materials that (1) interfere with anyone else's use of the Site; (2) are abusive, illegal, indecent, obscene, offensive, or threatening in any way; (3) encourage anyone to break the law; (4) violate anyone's copyright or other property right; (5) interfere with the privacy of any other user; (6) contain a virus or any other harmful component; or (7) contain false or misleading statements of fact or descriptions of the origin of the material or the communication. You agree to comply with any additional terms which are referred to on this Site or any subsite within the website.
# Responsibility for User's Material
# You are prohibited from posting or transmitting any defamatory, libelous, obscene, pornographic, profane, threatening, or unlawful material or any material that could constitute or encourage conduct that would be considered a criminal offense or give rise to civil liability, or otherwise violate any law. Although Last Sandwich may from time to time monitor or review bulletin boards, chatrooms, discussions, postings, transmissions, and the like on the Site, Last Sandwich is under no obligation to do so and assumes no liability or responsibility arising from the contents of any such communications or for any defamation, error, inaccuracy, libel, obscenity, or profanity contained in any such communication. Last Sandwich may change, edit, or remove any user material or conversations that are illegal, indecent, obscene, or offensive, or that violate Last Sandwich's policies in any way. Last Sandwich will fully cooperate with any law enforcement authorities or court order requesting or directing Last Sandwich to disclose the identity of anyone posting such materials.
# Last Sandwich's Rights to User's Material
# If you send any communications or materials to the Site by electronic mail or otherwise, including any comments, data, questions, suggestions, or the like, all such communications are, and will be treated as, non-confidential and non- proprietary. Thus, you give up any claim that any use of such material violates any of your rights including moral rights, privacy rights, proprietary or other property rights, publicity rights, rights to credit for material or ideas, or any other right, including the right to approve the way Last Sandwich uses such material.
# Any material submitted to this Site may be adapted, broadcast, changed, copied, disclosed, licensed, performed, posted, published, sold, transmitted, or used by Last Sandwich anywhere in the world, in any medium, forever. Furthermore, Last Sandwich is free to use, without any compensation to you, any concepts, ideas, know-how, or techniques contained in any communication you send to the Site for any purpose whatsoever, including but not limited to developing, manufacturing, and marketing products using such information. However, you agree and understand that Last Sandwich is not obligated to use any such ideas or materials, and you have no rights to compel such use.
# Transmitted Material
# Internet transmissions are never completely private or secure. You understand that any message or information you send to this Site may be read or intercepted by others, unless there is a special notice that a particular message (for example, credit card information) is encrypted (sent in code). Sending a message to Last Sandwich does not cause Last Sandwich to have any special responsibility to you.
# Links
# This website may contain links to other Internet sites on the World Wide Web. Last Sandwich provides such links for your convenience only, and is not responsible for the content of any website linked to or from this Site. Links from this Site to any other website do not mean that Last Sandwich approves of, endorses, or recommends that website. Last Sandwich disclaims all warranties, express or implied, as to the accuracy, legality, reliability, or validity of any content on any other website.
# Contests
# This Site may contain contests that offer prizes or that require you to send in material or information about yourself. Each contest has its own rules, which you must read and agree to before you may enter.
# Rules for Kids (Under Age 16)
# If you are under 16, you should ask your parents or a guardian before you:
#     E-mail the Site, or ask us to e-mail anything to you
#     Send in any information
#     Enter any contest or game that requires information about you or offers a prize
#     Join any club or group
#     Post any information on any bulletin board or enter any chatroom or
#     Buy anything online
# Availability of Products and Services
# The products and services displayed on the Site may not be available for purchase in your particular country or locality. The reference to such products and services on the Site does not imply or warrant that these products or services will be available at any time in your particular location. You should check with your local Last Sandwich authorized representative for the availability of specific products and services in your area.
# Last Sandwich's Right to Change These Terms and Conditions of Use or Content on the Site
# Last Sandwich may add to, change, or remove any part of these Terms and Conditions of Use at any time, without notice. Any changes to these Terms and Conditions of Use or any terms posted on this Site apply as soon as they are posted. By continuing to use this Site after any changes are posted, you are indicating your acceptance of those changes. Last Sandwich may add, change, discontinue, remove, or suspend any other Content posted on this Site, including features and specifications of products described or depicted on the Site, temporarily or permanently, at any time, without notice and without liability.
# Indemnification
# You agree to indemnify, defend, and hold Last Sandwich and all of its agents, directors, employees, information providers, licensors and licensees, officers, and parent (collectively, &quot;Indemnified Parties&quot;), harmless from and against any and all liability and costs (including, without limitation, attorneys' fees and costs), incurred by the Indemnified Parties in connection with any claim arising out of any breach by you of these Terms and Conditions of Use or the foregoing representations, warranties, and covenants. You will cooperate as fully as reasonably required in Last Sandwich's defense of any claim. Last Sandwich reserves the right, at its own expense, to assume the exclusive defense and control of any matter otherwise subject to indemnification by you and you shall not in any event settle any matter without the written consent of Last Sandwich.
# Disclaimer of Warranties and Damages; Limitation of Liability
# YOUR USE OF THIS SITE IS AT YOUR OWN RISK. THIS SITE (INCLUDING ALL CONTENT AND FUNCTIONS MADE AVAILABLE ON OR ACCESSED THROUGH THIS SITE) IS PROVIDED &quot;AS IS.&quot; TO THE FULLEST EXTENT PERMISSIBLE BY LAW, WITH REGARD TO THE CONTENT ON THIS SITE, Last Sandwich MAKES NO REPRESENTATIONS OR WARRANTIES OF ANY KIND WHATSOEVER (1) FOR THE ACCURACY, MERCHANTABILITY, FITNESS FOR A PARTICULAR PURPOSE, OR NON-INFRINGEMENT OF ANY CONTENT PUBLISHED ON OR AVAILABLE THROUGH THE SITE; (2) THAT THE SERVER THAT MAKES THIS SITE AVAILABLE IS FREE OF VIRUSES OR OTHER COMPONENTS THAT MAY INFECT, HARM, OR CAUSE DAMAGE TO YOUR COMPUTER EQUIPMENT OR ANY OTHER PROPERTY WHEN YOU ACCESS, BROWSE, DOWNLOAD FROM, OR OTHERWISE USE THE SITE.
# UNDER NO CIRCUMSTANCES, INCLUDING BUT NOT LIMITED TO Last Sandwich'S NEGLIGENCE, SHALL Last Sandwich BE LIABLE FOR ANY CONSEQUENTIAL, DIRECT, INCIDENTAL, INDIRECT, PUNITIVE, OR SPECIAL DAMAGES RELATED TO (A) THE USE OF, (B) THE INABILITY TO USE, OR (C) ERRORS OR OMISSIONS IN THE CONTENTS AND FUNCTIONS OF THIS SITE, EVEN IF Last Sandwich OR AN AUTHORIZED REPRESENTATIVE THEREOF HAS BEEN ADVISED OF THE POSSIBILITY OF SUCH DAMAGES. SOME STATES DO NOT ALLOW THE EXCLUSION OR LIMITATION OF CONSEQUENTIAL OR INCIDENTAL DAMAGES, SO THE ABOVE LIMITATION OR EXCLUSION MAY NOT APPLY TO YOU. IN NO EVENT SHALL Last Sandwich'S TOTAL LIABILITY TO YOU FOR ALL DAMAGES, LOSSES, AND CAUSES OF ACTION (WHETHER IN CONTRACT OR TORT, INCLUDING, BUT NOT LIMITED TO, NEGLIGENCE OR OTHERWISE) EXCEED $100.00. General Provisions
# These Terms and Conditions of Use and any additional terms posted on this Site together constitute the entire agreement between Last Sandwich and you with respect to your use of this Site. Any cause of action you may have with respect to your use of this Site must be commenced within one (1) year after the claim or cause of action arises. If for any reason a court of competent jurisdiction finds any provision of these Terms and Conditions of Use, or portion thereof, to be unenforceable, that provision shall be enforced to the maximum extent permissible so as to effect the intent of this agreement, and the remainder of these Terms and Conditions of Use shall continue in full force and effect. These Terms and Conditions of Use shall be governed by and construed in accordance with the laws of the State of New York, United States of America, without reference to its conflicts of law rules.
# " />
# 	<meta name="author" content="Joe Sandwich" />
# 	<meta name="description" content="In celebration of the 4th of July and the 245th Birthday of America, we have created a list honoring the last 50 plus years of Nathan's World Famous Hot Dog Eating Contest.  Over the last week, we have been searching for an easy-to-read list of previous contest winners to no avail, so we decided to create our own.  All-Time List of Nathan's Hot Dog Eating Champions" />
# 	<meta name="generator" content="Joomla! - Open Source Content Management" />
# 	<title>The Last Sandwich - Sandwich Sports - All-Time List of Nathan's Hot Dog Eating Champions</title>
# 	<link href="https://www.lastsandwich.com/articles/sandwich-sports/all-time-list-of-nathan-s-hot-dog-eating-champions" rel="canonical" />
# 	<link href="/templates/rt_xenon/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon" />
# 	<link href="https://cdn.jsdelivr.net/npm/simple-line-icons@2.4.1/css/simple-line-icons.css" rel="stylesheet" />
# 	<link href="/components/com_k2/css/k2.css?v=2.10.3&b=20200429" rel="stylesheet" />
# 	<link href="/components/com_flexicontent/librairies/jquery/css/ui-lightness/jquery-ui-1.9.2.css" rel="stylesheet" />
# 	<link href="/components/com_flexicontent/assets/css/flexicontent.css?2996b0d639945b78d924341d484908cc" rel="stylesheet" />
# 	<link href="/components/com_flexicontent/assets/css/j3x.css?2996b0d639945b78d924341d484908cc" rel="stylesheet" />
# 	<link href="https://www.lastsandwich.com/plugins/editors/dropeditor/dropeditor.css" rel="stylesheet" />
# 	<link href="https://www.lastsandwich.com/media/dropeditor/customstyles.css" rel="stylesheet" />
# 	<link href="https://www.lastsandwich.com/media/dropeditor/titlestyles.css" rel="stylesheet" />
# 	<link href="/components/com_seoglossary/assets/css/jqeasytooltip.css" rel="stylesheet" />
# 	<link href="https://www.lastsandwich.com/media/droptables/85_a6bfe91b903112b23896cec1359f0a9a.css" rel="stylesheet" />
# 	<link href="https://www.lastsandwich.com/components/com_droptables/assets/css/front.css?t=1" rel="stylesheet" />
# 	<link href="https://www.lastsandwich.com/components/com_droptables/assets/DataTables/datatables.min.css" rel="stylesheet" />
# 	<link href="https://www.lastsandwich.com/components/com_droptables/assets/tipso/tipso.css" rel="stylesheet" />
# 	<link href="/components/com_flexicontent/librairies/select2/select2.css?3.5.4" rel="stylesheet" />
# 	<link href="/components/com_flexicontent/librairies/bootstrap-toggle/css/bootstrap2-toggle.min.css" rel="stylesheet" />
# 	<link href="/components/com_flexicontent/assets/css/fcvote.css?2996b0d639945b78d924341d484908cc" rel="stylesheet" />
# 	<link href="/plugins/flexicontent_fields/fcpagenav/fcpagenav/fcpagenav.css" rel="stylesheet" />
# 	<link href="/components/com_flexicontent/templates/zenker-article/css/item.css" rel="stylesheet" />
# 	<link href="/components/com_flexicontent/assets/css/tabber.css?2996b0d639945b78d924341d484908cc" rel="stylesheet" />
# 	<link href="https://www.lastsandwich.com/plugins/system/nextprevpagenavigation/nextprevpagenavigation/css/stylenofa.css" rel="stylesheet" />
# 	<link href="https://www.lastsandwich.com/plugins/system/nextprevpagenavigation/nextprevpagenavigation/css/style6.css" rel="stylesheet" />
# 	<link href="/plugins/system/jcemediabox/css/jcemediabox.min.css?0072da39200af2a5f0dbaf1a155242cd" rel="stylesheet" />
# 	<link href="/plugins/system/jce/css/content.css?badb4208be409b1335b815dde676300e" rel="stylesheet" />
# 	<link href="/plugins/system/ampz/ampz/css/ampz.min.css" rel="stylesheet" />
# 	<link href="//fonts.googleapis.com/css?family=Open+Sans:400,600,700" rel="stylesheet" />
# 	<link href="/media/jui/css/chosen.css?e6c03ea46c8ec8ebbc240225d2c36f7a" rel="stylesheet" />
# 	<link href="/media/com_finder/css/finder.css?e6c03ea46c8ec8ebbc240225d2c36f7a" rel="stylesheet" />
# 	<link href="/modules/mod_maximenuck/themes/custom/css/maximenuck_maximenuck592.css" rel="stylesheet" />
# 	<link href="/media/gantry5/assets/css/lightcase.css" rel="stylesheet" />
# 	<link href="/media/gantry5/engines/nucleus/css-compiled/nucleus.css" rel="stylesheet" />
# 	<link href="/templates/rt_xenon/custom/css-compiled/xenon_63.css?64aab8d2" rel="stylesheet" />
# 	<link href="/media/gantry5/assets/css/bootstrap-gantry.css" rel="stylesheet" />
# 	<link href="/media/gantry5/engines/nucleus/css-compiled/joomla.css" rel="stylesheet" />
# 	<link href="/media/jui/css/icomoon.css" rel="stylesheet" />
# 	<link href="/media/gantry5/assets/css/font-awesome.min.css" rel="stylesheet" />
# 	<link href="/templates/rt_xenon/custom/css-compiled/xenon-joomla_63.css?64aab8d2" rel="stylesheet" />
# 	<link href="/templates/rt_xenon/custom/css-compiled/custom_63.css?64aab8d2" rel="stylesheet" />
# 	<link href="/media/plg_system_miniteksystemmessages/css/miniteksystemmessages.css?e6c03ea46c8ec8ebbc240225d2c36f7a" rel="stylesheet" />
# 	<link href="/media/plg_system_miniteksystemmessages/css/polipop.core.css?e6c03ea46c8ec8ebbc240225d2c36f7a" rel="stylesheet" />
# 	<link href="/media/plg_system_miniteksystemmessages/css/polipop.default.css?e6c03ea46c8ec8ebbc240225d2c36f7a" rel="stylesheet" />
# 	<style>
#
# abbr
# 			{
# 			border-bottom: 1px dotted;
# 			}
# 			span .jqeasytooltip {
# 			 border-bottom: 1px dashed;
# 			}
# 			/* This is via voting field parameter, please edit field configuration to override them */
# 			.voting-row div.fcvote.fcvote-box-main {
# 				line-height:24px!important;
# 			}
# 			.voting-row div.fcvote.fcvote-box-main > ul.fcvote_list {
# 				height:24px!important;
# 				width:120px!important;
# 			}
# 			.voting-row div.fcvote.fcvote-box-main > ul.fcvote_list > li.voting-links a,
# 			.voting-row div.fcvote.fcvote-box-main > ul.fcvote_list > li.current-rating {
# 				height:24px!important;
# 				line-height:24px!important;
# 			}
# 			.voting-row div.fcvote.fcvote-box-main > ul.fcvote_list,
# 			.voting-row div.fcvote.fcvote-box-main > ul.fcvote_list > li.voting-links a:hover,
# 			.voting-row div.fcvote.fcvote-box-main > ul.fcvote_list > li.current-rating {
# 				background-image:url(/components/com_flexicontent/assets/images/star-medium.png)!important;
# 			}
#
# 			/* This is via voting field parameter, please edit field configuration to override them */
# 			.voting-row div.fcvote > ul.fcvote_list {
# 				height:24px!important;
# 				width:120px!important;
# 			}
# 			.voting-row div.fcvote > ul.fcvote_list > li.voting-links a,
# 			.voting-row div.fcvote > ul.fcvote_list > li.current-rating {
# 				height:24px!important;
# 				line-height:24px!important;
# 			}
# 			.voting-row div.fcvote > ul.fcvote_list,
# 			.voting-row div.fcvote > ul.fcvote_list > li.voting-links a:hover,
# 			.voting-row div.fcvote > ul.fcvote_list > li.current-rating {
# 				background-image:url(/components/com_flexicontent/assets/images/star-medium.png)!important;
# 			}
# 			.voting-row div.fcvote ul.fcvote_list > .voting-links a.star1 { width: 20%!important; z-index: 6; }
# .voting-row div.fcvote ul.fcvote_list > .voting-links a.star2 { width: 40%!important; z-index: 5; }
# .voting-row div.fcvote ul.fcvote_list > .voting-links a.star3 { width: 60%!important; z-index: 4; }
# .voting-row div.fcvote ul.fcvote_list > .voting-links a.star4 { width: 80%!important; z-index: 3; }
# .voting-row div.fcvote ul.fcvote_list > .voting-links a.star5 { width: 100%!important; z-index: 2; }
# [data-id="maximenuck592"] .mobilemenuck-item-counter {
# 	display: inline-block;
# 	margin: 0 5px;
# 	padding: 10px;
# 	font-size: 12px;
# 	line-height: 0;
# 	background: rgba(0,0,0,0.3);
# 	color: #eee;
# 	border-radius: 10px;
# 	height: 20px;
# 	transform: translate(10px,-3px);
# 	box-sizing: border-box;
# }/* Mobile Menu CK - https://www.joomlack.fr */
# /* Automatic styles */
#
# .mobilemenuck-bar {display:none;position:relative;left:0;top:0;right:0;z-index:100;}
# .mobilemenuck-bar-title {display: block;}
# .mobilemenuck-bar-button {cursor:pointer;box-sizing: border-box;position:absolute; top: 0; right: 0;line-height:0.8em;font-family:Segoe UI;text-align: center;}
# .mobilemenuck {box-sizing: border-box;width: 100%;}
# .mobilemenuck-topbar {position:relative;}
# .mobilemenuck-title {display: block;}
# .mobilemenuck-button {cursor:pointer;box-sizing: border-box;position:absolute; top: 0; right: 0;line-height:0.8em;font-family:Segoe UI;text-align: center;}
# .mobilemenuck a {display:block;}
# .mobilemenuck a:hover {text-decoration: none;}
# .mobilemenuck .mobilemenuck-item > div {position:relative;}
# /* for accordion */
# .mobilemenuck-togglericon:after {cursor:pointer;text-align:center;display:block;position: absolute;right: 0;top: 0;content:"";}
# .mobilemenuck .open .mobilemenuck-togglericon:after {content:"";}
#
# [data-id="maximenuck592"] .mobilemenuck-bar-title {
# 	background: #444444;
# 	color: #EEEEEE;
# 	font-weight: normal;
# 	text-indent: 20px;
# 	line-height: 45px;
# 	font-size: 16px;
# }
#
# [data-id="maximenuck592"] .mobilemenuck-bar-title a {
# 	color: #EEEEEE;
# 	font-weight: normal;
# 	text-indent: 20px;
# 	line-height: 45px;
# 	font-size: 16px;
# }
#
# [data-id="maximenuck592"] .mobilemenuck-bar-button {
# 	background:  url(/media/com_mobilemenuck/presets/default/icon_launch.jpg) left center no-repeat ;
# 	height: 28px;
# 	width: 45px;
# 	margin-top: 8px;
# 	margin-right: 5px;
# 	margin-bottom: 5px;
# 	margin-left: 5px;
# }
#
# [data-id="maximenuck592"].mobilemenuck {
# 	background: #32373B;
# 	color: #FFFFFF;
# 	font-size: 15px;
# }
#
# [data-id="maximenuck592"].mobilemenuck a {
# 	color: #FFFFFF;
# 	font-size: 15px;
# }
#
# [data-id="maximenuck592"] .mobilemenuck-title {
# 	background:  url(/media/com_mobilemenuck/presets/default/fond_haut.jpg) center center no-repeat ;
# 	height: 45px;
# 	text-indent: 20px;
# 	line-height: 45px;
# 	font-size: 20px;
# }
#
# [data-id="maximenuck592"] .mobilemenuck-title a {
# 	text-indent: 20px;
# 	line-height: 45px;
# 	font-size: 20px;
# }
#
# [data-id="maximenuck592"] .mobilemenuck-button {
# 	background:  url(/media/com_mobilemenuck/presets/prototype/close.png) center center no-repeat ;
# 	height: 31px;
# 	width: 31px;
# 	margin-top: 5px;
# 	margin-right: 10px;
# 	margin-bottom: 5px;
# 	margin-left: 10px;
# 	line-height: 35px;
# }
#
# [data-id="maximenuck592"] .mobilemenuck-button a {
# 	line-height: 35px;
# }
#
# [data-id="maximenuck592"] .mobilemenuck-item > .level1 {
# 	background: #10223E;
# 	-moz-border-radius: 5px 5px 5px 5px;
# 	-o-border-radius: 5px 5px 5px 5px;
# 	-webkit-border-radius: 5px 5px 5px 5px;
# 	border-radius: 5px 5px 5px 5px;
# 	color: #FFFFFF;
# 	margin-top: 2px;
# 	margin-right: 10px;
# 	margin-bottom: 2px;
# 	margin-left: 10px;
# 	padding-left: 45px;
# 	line-height: 35px;
# }
#
# [data-id="maximenuck592"] .mobilemenuck-item > .level1 a {
# 	color: #FFFFFF;
# 	line-height: 35px;
# }
#
# [data-id="maximenuck592"] .mobilemenuck-item > .level2 {
# 	background: #0080C0;
# 	-moz-border-radius: 5px 5px 5px 5px;
# 	-o-border-radius: 5px 5px 5px 5px;
# 	-webkit-border-radius: 5px 5px 5px 5px;
# 	border-radius: 5px 5px 5px 5px;
# 	color: #FFFFFF;
# 	margin-top: 2px;
# 	margin-right: 10px;
# 	margin-bottom: 2px;
# 	margin-left: 20px;
# 	padding-left: 45px;
# 	line-height: 35px;
# }
#
# [data-id="maximenuck592"] .mobilemenuck-item > .level2 a {
# 	color: #FFFFFF;
# 	line-height: 35px;
# }
#
# [data-id="maximenuck592"] .level2 + .mobilemenuck-submenu .mobilemenuck-item > div {
# 	background: #0C6193;
# 	-moz-border-radius: 5px 5px 5px 5px;
# 	-o-border-radius: 5px 5px 5px 5px;
# 	-webkit-border-radius: 5px 5px 5px 5px;
# 	border-radius: 5px 5px 5px 5px;
# 	color: #FFFFFF;
# 	margin-top: 2px;
# 	margin-right: 10px;
# 	margin-bottom: 2px;
# 	margin-left: 30px;
# 	padding-left: 45px;
# 	line-height: 35px;
# }
#
# [data-id="maximenuck592"] .level2 + .mobilemenuck-submenu .mobilemenuck-item > div a {
# 	color: #FFFFFF;
# 	line-height: 35px;
# }
#
# [data-id="maximenuck592"] .mobilemenuck-togglericon:after {
# 	background:  url(/media/com_mobilemenuck/presets/prototype/plus.png) center center no-repeat ;
# 	height: 35px;
# 	width: 35px;
# 	margin-right: 30px;
# }
# [data-id="maximenuck592"] .mobilemenuck {
#     text-shadow: 1px -1px 2px #000;
# }
#
# [data-id="maximenuck592"] .mobilemenuck div span.descck {
#     padding-left: 10px;
#     font-size: 12px;
# }
#
# [data-id="maximenuck592"] .mobilemenuck div.level4 > a {
#     padding-left: 85px;
# }
#
# [data-id="maximenuck592"] .mobilemenuck div.level5 > a {
#     padding-left: 95px;
# }
#
# /* for accordeon */
# [data-id="maximenuck592"] .open .mobilemenuck-togglericon:after {
# 	background-image: url(/media/com_mobilemenuck/presets/prototype/minus.png);
# }[data-id="maximenuck592"] img.mobilemenuck-icon {
# width: 32px;
# height: 32px;
# margin: 5px;
# }[data-id="maximenuck592"] i.mobilemenuck-icon {
# font-size: 32px;
# margin: 5px;
# .nav-growpop .wrap-icon {
#                         border: 0px solid #cdcdcd;
#                         background-color: #cdcdcd;
#                     }
#                     .nav-growpop div {
#                         background-color:#ffffff;
#                     }
#                     .nav-growpop h3{
#                         color: #e74c3c;
#                     }
#                     .nav-growpop a{
#                         top: 20%;
#                     }
#                     .nav-growpop span{
#                         color:#000000;
#                         border-bottom: 1px solid #000000;
#
#
#         .thumbimg{
#             width:99px;
#             height:auto;
#         }
#         #ikon{
#             margin-top:115%;
#         }
#         .linkc{
#            text-decoration: none;
#            color: #000000;
#         }
#
#         .linkc:hover {
#          text-decoration: none !important;
#          color: #e74c3c !important;
#         }
#
#
#
#
#
#         #ampz_inline_mobile { background-color: #ffffff }
#         @media (min-width: 600px) {
#             #ampz_inline_mobile {
#                 display: none !important;
#             }
#         }
#         @media (max-width: 600px) {
#             #ampz_inline_mobile {
#                 display: block !important;
#             }
# .mfp-content{
# 			font-family: 'Open Sans', helvetica, arial, sans-serif;
#
# #maximenuck592-mobile-bar, #maximenuck592-mobile-bar-wrap-topfixed { display: none; }
# 	@media only screen and (max-width:99999px){
# 	#maximenuck592 { display: none !important; }
# 	#maximenuck592-mobile-bar, #maximenuck592-mobile-bar-wrap-topfixed { display: block; }
# 	.mobilemenuck-hide {display: none !important;}
# #system-message-container {
# 			display: none;
#
# 			.polipop_theme_default .polipop__notification_type_success,
# 			.polipop_theme_compact .polipop__notification_type_success {
# 				background-color: #0ec47d;
# 				color: #ffffff;
# 			}
# 			.polipop_theme_default .polipop__notification_type_success .polipop__notification-icon svg,
# 			.polipop_theme_compact .polipop__notification_type_success .polipop__notification-icon svg {
# 				fill: #ffffff;
# 			}
# 			.polipop_theme_default .polipop__notification_type_info,
# 			.polipop_theme_compact .polipop__notification_type_info {
# 				background-color: #00b1fe;
# 				color: #ffffff;
# 			}
# 			.polipop_theme_default .polipop__notification_type_info .polipop__notification-icon svg,
# 			.polipop_theme_compact .polipop__notification_type_info .polipop__notification-icon svg {
# 				fill: #ffffff;
# 			}
# 			.polipop_theme_default .polipop__notification_type_warning,
# 			.polipop_theme_compact .polipop__notification_type_warning {
# 				background-color: #ffc107;
# 				color: #555555;
# 			}
# 			.polipop_theme_default .polipop__notification_type_warning .polipop__notification-icon svg,
# 			.polipop_theme_compact .polipop__notification_type_warning .polipop__notification-icon svg {
# 				fill: #555555;
# 			}
# 			.polipop_theme_default .polipop__notification_type_error,
# 			.polipop_theme_compact .polipop__notification_type_error {
# 				background-color: #f76860;
# 				color: #ffffff;
# 			}
# 			.polipop_theme_default .polipop__notification_type_error .polipop__notification-icon svg,
# 			.polipop_theme_compact .polipop__notification_type_error .polipop__notification-icon svg {
# 				fill: #ffffff;
# 			}
#
# 	</style>
# 	<script type="application/json" class="joomla-script-options new">{"csrf.token":"b96951859de4b13dcd17a233fc3e0701","system.paths":{"root":"","base":""},"joomla.jtext":{"FLEXI_FORM_IS_BEING_SUBMITTED":"Form is being submitted ...","FLEXI_LOADING":"loading","COM_DROPTABLES_HIDDEN_COLUMNS_BUTTON":"Columns","FLEXI_NOT_AN_IMAGE_FILE":"FLEXI_NOT_AN_IMAGE_FILE","FLEXI_IMAGE":"Image","FLEXI_LOADING_IMAGES":"FLEXI_LOADING_IMAGES","FLEXI_THUMBNAILS":"FLEXI_THUMBNAILS","FLEXI_NO_ITEMS_SELECTED":"FLEXI_NO_ITEMS_SELECTED","FLEXI_ARE_YOU_SURE":"FLEXI_ARE_YOU_SURE","FLEXI_APPLYING_FILTERING":"Applying Filtering","FLEXI_TYPE_TO_LIST":"... type to list","FLEXI_TYPE_TO_FILTER":" ... type to filter","FLEXI_UPDATING_CONTENTS":"Updating contents ...","FLEXI_YOUR_BROWSER_DOES_NOT_SUPPORT_AJAX":"Your browser does not support Ajax","FLEXI_ADDED_TO_YOUR_FAVOURITES":"Added to your favourites","FLEXI_YOU_NEED_TO_LOGIN":"You need to login to favour this item. It will be added to your personal Favourites list.","FLEXI_REMOVED_FROM_YOUR_FAVOURITES":"Removed from your favourites","FLEXI_USERS":"users","FLEXI_FAVOURE":"Add to favourites","FLEXI_REMOVE_FAVOURITE":"Remove from your favourites","FLEXI_FAVS_YOU_HAVE_SUBSCRIBED":"You have subscribed","FLEXI_FAVS_CLICK_TO_SUBSCRIBE":"Click to subscribe","FLEXI_TOTAL":"Total","FLEXI_PUBLISHED":"Published","FLEXI_UNPUBLISHED":"Unpublished","FLEXI_IN_PROGRESS":"In progress","FLEXI_PENDING":"Pending","FLEXI_TO_WRITE":"Draft","FLEXI_ARCHIVED":"Archived","FLEXI_TRASHED":"Trashed"},"system.keepalive":{"interval":3540000,"uri":"\/component\/ajax\/?format=json"},"miniteksystemmessages":{"token":"b96951859de4b13dcd17a233fc3e0701","site_path":"https:\/\/www.lastsandwich.com\/","is_site":true,"user_id":0,"application_messages":[],"session_message":false,"session_redirect_link":"\/articles\/sandwich-sports\/all-time-list-of-nathan-s-hot-dog-eating-champions","lifetime":"60","actions_log":false,"logged_users":false,"error_text":"Error","success_text":"Message","notice_text":"Notice","warning_text":"Warning","appendTo":"body","position":"bottom-right","layout":"popups","theme":"default","icons":true,"insert":"before","spacing":10,"pool":0,"sticky":false,"life":9000,"progressbar":true,"pauseOnHover":true,"headerText":"Messages","closer":true,"closeText":"Close","loadMoreText":"Load more","hideEmpty":false,"effect":"fade","easing":"linear","effectDuration":250,"group_messages":false}}</script>
# 	<script src="/media/jui/js/jquery.min.js?e6c03ea46c8ec8ebbc240225d2c36f7a"></script>
# 	<script src="/media/jui/js/jquery-noconflict.js?e6c03ea46c8ec8ebbc240225d2c36f7a"></script>
# 	<script src="/media/jui/js/jquery-migrate.min.js?e6c03ea46c8ec8ebbc240225d2c36f7a"></script>
# 	<script src="/media/k2/assets/js/k2.frontend.js?v=2.10.3&b=20200429&sitepath=/"></script>
# 	<script src="/media/system/js/core.js?e6c03ea46c8ec8ebbc240225d2c36f7a"></script>
# 	<script src="/media/jui/js/jquery.ui.core.min.js?e6c03ea46c8ec8ebbc240225d2c36f7a"></script>
# 	<script src="/media/jui/js/jquery.ui.sortable.min.js?e6c03ea46c8ec8ebbc240225d2c36f7a"></script>
# 	<script src="/components/com_flexicontent/librairies/jquery/js/jquery-ui/jquery.ui.dialog.min.js"></script>
# 	<script src="/components/com_flexicontent/librairies/jquery/js/jquery-ui/jquery.ui.menu.min.js"></script>
# 	<script src="/components/com_flexicontent/librairies/jquery/js/jquery-ui/jquery.ui.autocomplete.min.js"></script>
# 	<script src="/components/com_flexicontent/librairies/jquery/js/jquery-ui/jquery.ui.progressbar.min.js"></script>
# 	<script src="/components/com_seoglossary/assets/js/jqeasytooltip.v1.3.js"></script>
# 	<script src="https://www.lastsandwich.com/components/com_droptables/assets/js/moment.min.js"></script>
# 	<script src="https://www.lastsandwich.com/components/com_droptables/assets/js/moment-jdateformatparser.js"></script>
# 	<script src="https://www.lastsandwich.com/components/com_droptables/assets/DataTables/datatables.min.js"></script>
# 	<script src="https://www.lastsandwich.com/components/com_droptables/assets/tipso/tipso.js"></script>
# 	<script src="https://www.lastsandwich.com/components/com_droptables/assets/js/jquery.fileDownload.js?v=4.0.2"></script>
# 	<script src="https://www.lastsandwich.com/components/com_droptables/assets/js/front.js?v=4.0.2"></script>
# 	<script src="/media/jui/js/bootstrap.min.js?e6c03ea46c8ec8ebbc240225d2c36f7a"></script>
# 	<!--[if lt IE 9]><script src="/media/system/js/polyfill.event.js?e6c03ea46c8ec8ebbc240225d2c36f7a"></script><![endif]-->
# 	<!--[if lte IE 11]><script src="/media/system/js/polyfill.classlist.js?e6c03ea46c8ec8ebbc240225d2c36f7a"></script><![endif]-->
# 	<!--[if lte IE 11]><script src="/media/system/js/polyfill.map.js?e6c03ea46c8ec8ebbc240225d2c36f7a"></script><![endif]-->
# 	<script src="/components/com_flexicontent/assets/js/flexi-lib.js?2996b0d639945b78d924341d484908cc"></script>
# 	<script src="/components/com_flexicontent/librairies/mousewheel/jquery.mousewheel.min.js"></script>
# 	<script src="/components/com_flexicontent/librairies/select2/select2.min.js?3.5.4"></script>
# 	<script src="/components/com_flexicontent/librairies/select2/select2.sortable.js?3.5.4"></script>
# 	<script src="/components/com_flexicontent/assets/js/tmpl-common.js?2996b0d639945b78d924341d484908cc"></script>
# 	<script src="/components/com_flexicontent/assets/js/jquery-easing.js?2996b0d639945b78d924341d484908cc"></script>
# 	<script src="/components/com_flexicontent/librairies/bootstrap-toggle/js/bootstrap2-toggle.min.js"></script>
# 	<script src="/components/com_flexicontent/assets/js/fcfav.js?2996b0d639945b78d924341d484908cc"></script>
# 	<script src="/components/com_flexicontent/assets/js/fcvote.js?2996b0d639945b78d924341d484908cc"></script>
# 	<script src="/components/com_flexicontent/assets/js/tabber-minimized.js?2996b0d639945b78d924341d484908cc"></script>
# 	<script src="/plugins/system/jcemediabox/js/jcemediabox.min.js?d67233ea942db0e502a9d3ca48545fb9"></script>
# 	<script src="/plugins/system/ampz/ampz/js/ampz.min.js"></script>
# 	<script src="/media/system/js/keepalive.js?e6c03ea46c8ec8ebbc240225d2c36f7a"></script>
# 	<script src="/media/jui/js/chosen.jquery.min.js?e6c03ea46c8ec8ebbc240225d2c36f7a"></script>
# 	<script src="/media/jui/js/jquery.autocomplete.min.js?e6c03ea46c8ec8ebbc240225d2c36f7a"></script>
# 	<script src="/media/plg_system_mobilemenuck/assets/mobilemenuck.js?ver=1.5.9"></script>
# 	<script src="/media/plg_system_miniteksystemmessages/js/polipop.js?e6c03ea46c8ec8ebbc240225d2c36f7a"></script>
# 	<script src="/media/plg_system_miniteksystemmessages/js/miniteksystemmessages.js"></script>
# 	<script>
#
# 				var jbase_url_fc = "https:\/\/www.lastsandwich.com\/";
# 				var jroot_url_fc = "https:\/\/www.lastsandwich.com\/";
# 				var jclient_path_fc = "";
# jQuery(function($){ initTooltips(); $("body").on("subform-row-add", initTooltips); function initTooltips (event, container) { container = container || document;$(container).find(".hasTooltip").tooltip({"html": true,"container": "body"});} });
# 					var fc_sef_lang = 'en';
# 					var fc_root_uri = '';
# 					var fc_base_uri = '';
# 					var FC_URL_VARS = [];
#
# 					jQuery( document ).ready(function() {
# 						jQuery("body").prepend('\
# 							<div id="fc_filter_form_blocker" style="display: none;">\
# 								<div class="fc_blocker_overlay" style="background-color: rgba(0, 0, 0, 0.3);"></div>\
# 								<div class="fc_blocker_content" style="background-color: rgba(255, 255, 255, 1); color: rgba(0, 0, 0, 1);">\
# 									\
# 									<div class="fc_blocker_mssg" style="" >Applying Filtering</div>\
# 									<div class="fc_blocker_bar"><div style="background-color: rgba(0, 153, 255, 1);"></div></div>\
# 								</div>\
# 							</div>\
# 						');
# 					});
#
# 				if (typeof jQuery.fn.chosen == 'function') {
# 					jQuery.fn.chosen_fc = jQuery.fn.chosen;
# 					jQuery.fn.chosen = function(){
# 						var args = arguments;
# 						var result;
# 						jQuery(this).each(function() {
# 							if (jQuery(this).hasClass('use_select2_lib') || jQuery(this).hasClass('fc_no_js_attach')) return;
# 							result = jQuery(this).chosen_fc(args);
# 						});
# 						return result;
# 					};
# 				}
#
# 					jQuery(document).ready(function()
# 					{
# 						window.skip_select2_js = 0;
# 						fc_attachSelect2('body');
# 					});
#
# 					jQuery(document).ready(function(){
# 						jQuery('input.fc_checkboxtoggle').bootstrapToggle();
# 					});
#
# 		var fcfav_toggle_style = 2;
# 		var fcfav_status_info = 0;
# 		var fcfav_toggle_info = 1;
#  document.write('<style type="text/css">.fctabber{display:none;}<\/style>');
# 				var _fc_state_titles = { '1' : 'FLEXI_PUBLISHED' , '0' : 'FLEXI_UNPUBLISHED' , '-5' : 'FLEXI_IN_PROGRESS' , '-3' : 'FLEXI_PENDING' , '-4' : 'FLEXI_TO_WRITE' , '2' : 'FLEXI_ARCHIVED' , '-2' : 'FLEXI_TRASHED'};
#
# 		var fc_validateOnSubmitForm = 1;
#
#                     [].slice.call( document.querySelectorAll('.mobinavjx > a') ).forEach( function(el) {
#                         el.addEventListener( 'click', function(ev) { ev.preventDefault(); } );
#                     } );
# var ampzSettings = {"ampzCounts":"","ampzNetworks":["facebook","twitter","pinterest","pocket","line","email","blogger","gmail","youtube","instagram","print"],"ampzEntranceDelay":"1.5s","ampzEntranceDelayMobile":"1.5s","ampzMobileOnlyButtons":"","ampzMobileWidth":"600","ampzFlyinEntranceEffect":"ampz_flyin_right bounceInUp","ampzThresholdTotalShares":"0","ampzBaseUrl":"https:\/\/www.lastsandwich.com\/","ampzShareUrl":"https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions","ampzOpenInNewTab":"","ampzFbAT":"0","ampzCacheLifetime":"3600","ampzCachedCounts":"","ampzFlyInTriggerBottom":"","ampzFlyInTriggerTime":"","ampzFlyInTriggerTimeSeconds":"10000","ampzActiveComponent":"com_flexicontent","ampzFlyInDisplayMobile":"","ampzInlineDisplayMobile":"","ampzInlineDisableExpandOnHover":"","ampzSidebarDisplayMobile":"","ampzFlyInCookieType":"never","ampzFlyInCookieDuration":"5","ampzSideBarVisibility":"inline","ampzMobileVisibility":"inline","ampzSideBarStartClosed":""};
# 	jQuery(function ($) {
# 		initChosen();
# 		$("body").on("subform-row-add", initChosen);
#
# 		function initChosen(event, container)
# 		{
# 			container = container || document;
# 			$(container).find(".advancedSelect").chosen({"disable_search_threshold":10,"search_contains":true,"allow_single_deselect":true,"placeholder_text_multiple":"Type or select some options","placeholder_text_single":"Select an option","no_results_text":"No results match"});
# 		}
# 	});
#
# jQuery(document).ready(function() {
# 	var value, searchword = jQuery('#mod-finder-searchword548');
#
# 		// Get the current value.
# 		value = searchword.val();
#
# 		// If the current value equals the default value, clear it.
# 		searchword.on('focus', function ()
# 		{
# 			var el = jQuery(this);
#
# 			if (el.val() === 'Search ...')
# 			{
# 				el.val('');
# 			}
# 		});
#
# 		// If the current value is empty, set the previous value.
# 		searchword.on('blur', function ()
# 		{
# 			var el = jQuery(this);
#
# 			if (!el.val())
# 			{
# 				el.val(value);
# 			}
# 		});
#
# 		jQuery('#mod-finder-searchform548').on('submit', function (e)
# 		{
# 			e.stopPropagation();
# 			var advanced = jQuery('#mod-finder-advanced548');
#
# 			// Disable select boxes with no value selected.
# 			if (advanced.length)
# 			{
# 				advanced.find('select').each(function (index, el)
# 				{
# 					var el = jQuery(el);
#
# 					if (!el.val())
# 					{
# 						el.attr('disabled', 'disabled');
# 					}
# 				});
# 			}
# 		});
# 	var suggest = jQuery('#mod-finder-searchword548').autocomplete({
# 		serviceUrl: '/component/finder/?task=suggestions.suggest&amp;format=json&amp;tmpl=component',
# 		paramName: 'q',
# 		minChars: 1,
# 		maxHeight: 400,
# 		width: 300,
# 		zIndex: 9999,
# 		deferRequestBy: 500
# jQuery(document).ready(function(){ new MobileMenuCK(jQuery('#maximenuck592'), {menubarbuttoncontent : '',topbarbuttoncontent : '',showmobilemenutext : 'default',mobilemenutext : 'Menu',container : 'topfixed',detectiontype : 'resolution',resolution : '99999',usemodules : '0',useimages : '0',showlogo : '0',showdesc : '0',displaytype : 'accordion',displayeffect : 'slideleft',menuwidth : '300',openedonactiveitem : '0',mobilebackbuttontext : 'Back',menuselector : 'ul.maximenuck',uriroot : '',tooglebarevent : 'click',tooglebaron : 'all',logo_source : 'maximenuck',logo_image : '',logo_link : '',logo_alt : '',logo_position : 'left',logo_width : '',logo_height : '',logo_margintop : '',logo_marginright : '',logo_marginbottom : '',logo_marginleft : '',topfixedeffect : 'always',lock_button : '1',lock_forced : '0',accordion_use_effects : '0',accordion_toggle : '0',show_icons : '1',counter : '0',hide_desktop : '1',menuid : 'maximenuck592',merge : '',beforetext : '',aftertext : '',mergeorder : '',logo_where : '1',uriroot : ''}); });
# 	</script>
# 	<script type='text/javascript'>
#                 /*<![CDATA[*/
#                     var jax_live_site = 'https://www.lastsandwich.com/index.php';
#                     var jax_token_var='b96951859de4b13dcd17a233fc3e0701';
#                 /*]]>*/
#                 </script><script type="text/javascript" src="/plugins/system/jomsocial.system/pc_includes/ajax_1.5.pack.js"></script>
# 	<!--[if IE 8]>
# 				<link href="/components/com_flexicontent/assets/css/ie8.css?2996b0d639945b78d924341d484908cc" rel="stylesheet" />
# 				<![endif]-->
# 	<meta property="og:description" content="In celebration of the 4th of July and the 245th Birthday of America, we have created a list honoring the last 50 plus years of Nathan's World Famous Hot Dog Eating Contest.  Over the last week, we have been searching for an easy-to-read list of previous contest winners to no avail, so we decided to create our own.  All-Time List of Nathan's Hot Dog Eating Champions" />
# 	<script type='text/javascript'>function closeJQTip(id){ if(window.jQuery)
# 				{ jQuery('.jqeasytooltip'+id).jqeasytooltip(('close',{})); } }</script>
# 	<meta property="og:title" content="All-Time List of Nathan's Hot Dog Eating Champions" />
#
#
#                     <script data-ad-client="ca-pub-3272920559736024" async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
#
# </head>
#
#     <body class="item-id-78 item-catid-69 type-id-1 type-alias-article gantry site com_flexicontent view-item no-layout no-task dir-ltr itemid-493 outline-63 g-default g-style-preset6">
#
#
#
#
#         <div id="g-page-surround">
#
#
#
#         <div class="g-container">        <section id="g-top">
#                                         <div class="g-grid">
#
#         <div class="g-block size-36 medpaddingtop fp-top-b">
#              <div class="g-content">
#                                     <div class="moduletable ">
# 						<div id="module-social-390-particle" class="g-particle"><div class="g-social social">
#                                             <a href="http://www.facebook.com/lastsandwich" target="_blank" rel="noopener noreferrer">
#                 <span class="fa fa-lg fa-facebook fa-fw"></span>                <span class="g-social-text"></span>            </a>
#                                             <a href="http://www.twitter.com/last_sandwich" target="_blank" rel="noopener noreferrer">
#                 <span class="fa fa-lg fa-twitter fa-fw"></span>                <span class="g-social-text"></span>            </a>
#                                             <a href="https://www.youtube.com/@last_sandwich" target="_blank" rel="noopener noreferrer">
#                 <span class="fa fa-lg fa-youtube-play fa-fw"></span>                <span class="g-social-text"></span>            </a>
#                                             <a href="http://www.instagram.com/lastsandwich" target="_blank" rel="noopener noreferrer">
#                 <span class="fa fa-lg fa-instagram fa-fw"></span>                <span class="g-social-text"></span>            </a>
#             </div></div>		</div>
#
#         </div>
#         </div>
#
#
#         <div class="g-block size-28 center hidden-phone">
#              <div id="popupmodule-7126-particle" class="g-content g-particle">            <div class="">
#
# 	<div class="g-popupmodule">
# 		<div class="g-popupmodule-button">
# 			<div class="g-popupmodule-button-wrapper">
# 													<a data-rel="lightcase" href="#g-popupmodule-popupmodule-7126" title=""  class="button ">
# 						<span class="fa fa-user g-popupmodule-button-icon"></span>
# 					</a>
# 							</div>
#
# 			<div id="g-popupmodule-popupmodule-7126" class="g-popupmodule-module-wrapper">
# 				<div class="platform-content"><div class="moduletable ">
# 						<form action="https://www.lastsandwich.com/articles" method="post" id="login-form" class="form-inline">
# 			<div class="pretext">
# 			<p>Welcome to the Last Sandwich!
# <br /><br /></p>
# 		</div>
# 		<div class="userdata">
# 		<div id="form-login-username" class="control-group">
# 			<div class="controls">
# 									<div class="input-prepend">
# 						<span class="add-on">
# 							<span class="icon-user hasTooltip" title="Username"></span>
# 							<label for="modlgn-username" class="element-invisible">Username</label>
# 						</span>
# 						<input id="modlgn-username" type="text" name="username" class="input-small" tabindex="0" size="18" placeholder="Username" />
# 					</div>
# 							</div>
# 		</div>
# 		<div id="form-login-password" class="control-group">
# 			<div class="controls">
# 									<div class="input-prepend">
# 						<span class="add-on">
# 							<span class="icon-lock hasTooltip" title="Password">
# 							</span>
# 								<label for="modlgn-passwd" class="element-invisible">Password							</label>
# 						</span>
# 						<input id="modlgn-passwd" type="password" name="password" class="input-small" tabindex="0" size="18" placeholder="Password" />
# 					</div>
# 							</div>
# 		</div>
# 						<div id="form-login-remember" class="control-group checkbox">
# 			<label for="modlgn-remember" class="control-label">Remember Me</label> <input id="modlgn-remember" type="checkbox" name="remember" class="inputbox" value="yes"/>
# 		</div>
# 				<div id="form-login-submit" class="control-group">
# 			<div class="controls">
# 				<button type="submit" tabindex="0" name="Submit" class="btn btn-primary login-button">Log in</button>
# 			</div>
# 		</div>
# 					<ul class="unstyled">
# 							<li>
# 					<a href="/users/user-profile?view=registration">
# 					Create an account <span class="icon-arrow-right"></span></a>
# 				</li>
# 							<li>
# 					<a href="/users/user-name-request">
# 					Forgot your username?</a>
# 				</li>
# 				<li>
# 					<a href="/users/password-reset">
# 					Forgot your password?</a>
# 				</li>
# 			</ul>
# 		<input type="hidden" name="option" value="com_users" />
# 		<input type="hidden" name="task" value="user.login" />
# 		<input type="hidden" name="return" value="aHR0cHM6Ly93d3cubGFzdHNhbmR3aWNoLmNvbS9hcnRpY2xlcy9zYW5kd2ljaC1zcG9ydHMvYWxsLXRpbWUtbGlzdC1vZi1uYXRoYW4tcy1ob3QtZG9nLWVhdGluZy1jaGFtcGlvbnM=" />
# 		<input type="hidden" name="b96951859de4b13dcd17a233fc3e0701" value="1" />	</div>
# 	</form>
# 		</div></div>
# 			</div>
# 		</div>
# 	</div>
#
# </div>
#             </div>
#         </div>
#
#
#         <div class="g-block size-36 hidden-phone">
#              <div class="g-content">
#                                     <div class="platform-content"><div class="moduletable ">
#
# <div class="finder">
# ...
# 		</li><li data-level="2" class="maximenuck item252 level2 " style="z-index : 11981;" ><a  data-hover="Guidelines" class="maximenuck " href="/about-us/guidelines"><span class="titreck"  data-hover="Guidelines"><span class="titreck-text"><span class="titreck-title">Guidelines</span></span></span></a>
# 		</li><li data-level="2" class="maximenuck item119 last level2 " style="z-index : 11980;" ><a  data-hover="Contact Us" class="maximenuck " href="/about-us/contact-us"><span class="titreck"  data-hover="Contact Us"><span class="titreck-text"><span class="titreck-title">Contact Us</span></span></span></a>
# 	</li>
# 	</ul>
# 	</div></div></div>
# 	</li>            </ul>
#     </div>
#     <!-- fin maximenuCK -->
# 		</div></div>
#
#         </div>
#         </div>
#             </div>
#
#     </section></div>
#
#
#
#         </div>
#
#
#                         <script type="text/javascript" src="/media/gantry5/assets/js/main.js"></script>
#     <script type="text/javascript" src="/media/gantry5/assets/js/lightcase.js"></script>
#     <script type="text/javascript">jQuery(document).ready(function($) { jQuery('[data-rel^=lightcase]').lightcase({maxWidth: '100%', maxHeight: '100%', video: {width: '1280', height: '720'}}); });</script>
#
#
#
#
#
#     <div id="simgallery-container" class="simbunch-wrapper clearfix"></div><div class="nav-growpop mobinavjx">
#                     <a class="prev" href="/articles/sandwich-sports/joey-chestnut-legend-grows">
#                         <span class="wrap-icon"><i id="" class="fa fa-arrow-circle-left fa-2x linkc"></i></span>
#                         <div>
#                             <span>Prevous Story</span>
#                             <h3>Joey Chestnut Legend Grows</h3>
#                             <img class="thumbimg" src="https://www.lastsandwich.com/images/last-sandwich/articles-sports-sandwich/Joey-Chestnut-01.jpg" alt="Previous thumb"/>
#                         </div>
#                     </a>
#                     <a class="next" href="/articles/sandwich-sports/joey-chestnut-breaks-hot-dog-eating-record-again">
#                         <span class="wrap-icon"><i id="" class="fa fa-arrow-circle-right fa-2x linkc"></i></span>
#                         <div>
#                             <span>Next Story</span>
#                             <h3>Joey Chestnut Breaks Hot Dog Eating Record (Again)</h3>
#                             <img class="thumbimg" src="https://www.lastsandwich.com/images/last-sandwich/articles-sports-sandwich/Joey-Chestnut-beats-record-76.jpg" alt="Next thumb"/>
#                         </div>
#                     </a>
#                 </div><!-- start ampz sidebar --><div id="ampz_sidebar" style= "font-family: 'Open Sans', helvetica, arial, sans-serif" class="ampz_sidebar_right animated bounceInRight"  data-combineafter="5" data-buttontemplate="template_rotterdam" data-buttonsize="ampz_btn_normal" data-buttonwidth="auto">  <div class="ampz_container ampz_no_count"><ul>
#                             <li class="hvr-grow">
#         					    <a aria-label="sidebar_facebook" class="template_rotterdam ampz_btn ampz_btn_normal ampz_facebook " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="sidebar"  data-sharetype="facebook" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  href="#">
#         					        <i class="ampz ampz-icoon ampz-icoon-facebook"></i>
#                           <span class="ampz_network_label">Share</span></a>
#
#                             <li class="hvr-grow">
#         					    <a aria-label="sidebar_twitter" class="template_rotterdam ampz_btn ampz_btn_normal ampz_twitter " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="sidebar"  data-sharetype="twitter" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  data-via=@last_sandwich data-hashtags="lastsandwich,thelastsandwich"  href="#">
#         					        <i class="ampz ampz-icoon ampz-icoon-twitter"></i>
#                           <span class="ampz_network_label">Tweet</span></a>
#
#                             <li class="hvr-grow">
#         					    <a aria-label="sidebar_pinterest" class="template_rotterdam ampz_btn ampz_btn_normal ampz_pinterest " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="sidebar"  data-sharetype="pinterest" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  href="#">
#         					        <i class="ampz ampz-icoon ampz-icoon-pinterest"></i>
#                           <span class="ampz_network_label">Pin</span></a>
#
#                             <li class="hvr-grow">
#         					    <a aria-label="sidebar_pocket" class="template_rotterdam ampz_btn ampz_btn_normal ampz_pocket " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="sidebar"  data-sharetype="pocket" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  href="#">
#         					        <i class="ampz ampz-icoon ampz-icoon-pocket"></i>
#                           <span class="ampz_network_label">Share</span></a>
#
#                             <li class="hvr-grow">
#         					    <a aria-label="sidebar_line" class="template_rotterdam ampz_btn ampz_btn_normal ampz_line " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="sidebar"  data-sharetype="line" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  href="#">
#         					        <i class="ampz ampz-icoon ampz-icoon-line"></i>
#                           <span class="ampz_network_label">Share</span></a>
#
#                             <li class="hvr-grow">
#         					    <a aria-label="sidebar_email" class="template_rotterdam ampz_btn ampz_btn_normal ampz_email " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="sidebar"  data-sharetype="email" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  href="mailto:?subject=Check out this page: The Last Sandwich - Sandwich Sports - All-Time List of Nathan&#039;s Hot Dog Eating Champions&amp;body=https://www.lastsandwich.com/articles/sandwich-sports/all-time-list-of-nathan-s-hot-dog-eating-champions">
#         					        <i class="ampz ampz-icoon ampz-icoon-email"></i>
#                           <span class="ampz_network_label">Email</span></a>
#
#                             <li class="hvr-grow">
#         					    <a aria-label="sidebar_blogger" class="template_rotterdam ampz_btn ampz_btn_normal ampz_blogger " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="sidebar"  data-sharetype="blogger" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  href="#">
#         					        <i class="ampz ampz-icoon ampz-icoon-blogger"></i>
#                           <span class="ampz_network_label">Share</span></a>
#
#                             <li class="hvr-grow">
#         					    <a aria-label="sidebar_gmail" class="template_rotterdam ampz_btn ampz_btn_normal ampz_gmail " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="sidebar"  data-sharetype="gmail" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  href="#">
#         					        <i class="ampz ampz-icoon ampz-icoon-gmail"></i>
#                           <span class="ampz_network_label">Share</span></a>
#
#                             <li class="hvr-grow">
#         					    <a aria-label="sidebar_print" class="template_rotterdam ampz_btn ampz_btn_normal ampz_print " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="sidebar"  data-sharetype="print" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  href="#">
#         					        <i class="ampz ampz-icoon ampz-icoon-print"></i>
#                           <span class="ampz_network_label">Print</span></a>
#
#                     </ul><span class="ampz_hide_sidebar"><i class="ampz ampz-icoon ampz-icoon-right-open"></i></span>
#                 </div>
#             </div><div class="ampz_show_sidebar"><i class="ampz ampz-icoon ampz-icoon-share"></i></div><!-- end ampz sidebar --><!-- start ampz inline_mobile --><div id="ampz_inline_mobile" style= "font-family: 'Open Sans', helvetica, arial, sans-serif" class="animated slideInUp"  data-combineafter="4" data-buttontemplate="template_rotterdam" data-buttonsize="ampz_btn_normal" data-buttonwidth="auto">  <div class="ampz_container ampz_no_count"><ul>
#                             <li class="">
#         					    <a aria-label="inline_mobile_facebook" class="template_rotterdam ampz_btn ampz_btn_normal ampz_facebook " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="inline_mobile"  data-sharetype="facebook" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  href="#">
#         					        <i class="ampz ampz-icoon ampz-icoon-facebook"></i>
#                           </a>
#
#                             <li class="">
#         					    <a aria-label="inline_mobile_twitter" class="template_rotterdam ampz_btn ampz_btn_normal ampz_twitter " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="inline_mobile"  data-sharetype="twitter" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  data-via=@last_sandwich data-hashtags="lastsandwich,thelastsandwich"  href="#">
#         					        <i class="ampz ampz-icoon ampz-icoon-twitter"></i>
#                           </a>
#
#                             <li class="">
#         					    <a aria-label="inline_mobile_pinterest" class="template_rotterdam ampz_btn ampz_btn_normal ampz_pinterest " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="inline_mobile"  data-sharetype="pinterest" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  href="#">
#         					        <i class="ampz ampz-icoon ampz-icoon-pinterest"></i>
#                           </a>
#
#                             <li class="">
#         					    <a aria-label="inline_mobile_pocket" class="template_rotterdam ampz_btn ampz_btn_normal ampz_pocket " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="inline_mobile"  data-sharetype="pocket" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  href="#">
#         					        <i class="ampz ampz-icoon ampz-icoon-pocket"></i>
#                           </a>
#
#                             <li class="">
#         					    <a aria-label="inline_mobile_line" class="template_rotterdam ampz_btn ampz_btn_normal ampz_line " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="inline_mobile"  data-sharetype="line" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  href="#">
#         					        <i class="ampz ampz-icoon ampz-icoon-line"></i>
#                           </a>
#
#                             <li class="">
#         					    <a aria-label="inline_mobile_email" class="template_rotterdam ampz_btn ampz_btn_normal ampz_email " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="inline_mobile"  data-sharetype="email" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  href="mailto:?subject=Check out this page: The Last Sandwich - Sandwich Sports - All-Time List of Nathan&#039;s Hot Dog Eating Champions&amp;body=https://www.lastsandwich.com/articles/sandwich-sports/all-time-list-of-nathan-s-hot-dog-eating-champions">
#         					        <i class="ampz ampz-icoon ampz-icoon-email"></i>
#                           </a>
#
#                             <li class="">
#         					    <a aria-label="inline_mobile_blogger" class="template_rotterdam ampz_btn ampz_btn_normal ampz_blogger " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="inline_mobile"  data-sharetype="blogger" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  href="#">
#         					        <i class="ampz ampz-icoon ampz-icoon-blogger"></i>
#                           </a>
#
#                             <li class="">
#         					    <a aria-label="inline_mobile_gmail" class="template_rotterdam ampz_btn ampz_btn_normal ampz_gmail " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="inline_mobile"  data-sharetype="gmail" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  href="#">
#         					        <i class="ampz ampz-icoon ampz-icoon-gmail"></i>
#                           </a>
#
#                             <li class="">
#         					    <a aria-label="inline_mobile_print" class="template_rotterdam ampz_btn ampz_btn_normal ampz_print " data-url="https%3A%2F%2Fwww.lastsandwich.com%2Farticles%2Fsandwich-sports%2Fall-time-list-of-nathan-s-hot-dog-eating-champions" data-basecount="0" data-shareposition="inline_mobile"  data-sharetype="print" data-text="The+Last+Sandwich+-+Sandwich+Sports+-+All-Time+List+of+Nathan%26%23039%3Bs+Hot+Dog+Eating+Champions"  href="#">
#         					        <i class="ampz ampz-icoon ampz-icoon-print"></i>
#                           </a>
#
#                     </ul>
#                 </div>
#             </div><!-- end ampz inline_mobile --></body>
# </html>

# %%
#Soup is now the variable for the HTML link 
hotdog = BeautifulSoup(hotdog_url)
type(hotdog) #Type shows you what the variable represents
# Out:
# bs4.BeautifulSoup

# %%
#Got the contents of ONLY the website table 
hot_table = hotdog.find('div', id = "droptablestable85")
print(hot_table)
# Out:
# <div class="droptablesresponsive dataTables-droptables droptablestable" data-tableid="droptableTbl85" id="droptablestable85"><table class="sortable disablePager" data-align="left" data-colwidths="[57,205,93,205,92,100,73,91,221]" data-format="mm/dd/yyyy" data-hidecols="false" data-hidecolumn="[0,0,0,0,0,0,0,0,0]" data-id="85" data-ordering="true" data-ordertarget="0" data-ordervalue="desc" data-paging="false" data-responsive="false" data-scroll-collapse="true" data-scroll-x="true" data-searching="false" data-sort-format='["","","","","","","","",""]' data-sort-type='["","","","","","","","",""]' data-table-breakpoint="980" data-tbody="1" data-type="html" id="droptableTbl85"><colgroup><col class="dtc0" data-dtc="0" data-dtr="0"/><col class="dtc1" data-dtc="1" data-dtr="0"/><col class="dtc2" data-dtc="2" data-dtr="0"/><col class="dtc3" data-dtc="3" data-dtr="0"/><col class="dtc4" data-dtc="4" data-dtr="0"/><col class="dtc5" data-dtc="5" data-dtr="0"/><col class="dtc6" data-dtc="6" data-dtr="0"/><col class="dtc7" data-dtc="7" data-dtr="0"/><col class="dtc8" data-dtc="8" data-dtr="0"/></colgroup><thead><tr class="droptables-header-cells-index dnone"><th class="dtr0 dtc0" colspan="1" data-dtc="0" data-dtr="0" rowspan="1"></th><th class="dtr0 dtc1" colspan="1" data-dtc="1" data-dtr="0" rowspan="1"></th><th class="dtr0 dtc2" colspan="1" data-dtc="2" data-dtr="0" rowspan="1"></th><th class="dtr0 dtc3" colspan="1" data-dtc="3" data-dtr="0" rowspan="1"></th><th class="dtr0 dtc4" colspan="1" data-dtc="4" data-dtr="0" rowspan="1"></th><th class="dtr0 dtc5" colspan="1" data-dtc="5" data-dtr="0" rowspan="1"></th><th class="dtr0 dtc6" colspan="1" data-dtc="6" data-dtr="0" rowspan="1"></th><th class="dtr0 dtc7" colspan="1" data-dtc="7" data-dtr="0" rowspan="1"></th><th class="dtr0 dtc8" colspan="1" data-dtc="8" data-dtr="0" rowspan="1"></th></tr><tr class="row0"><th class="dtr0 dtc0" data-priority="0">Year</th><th class="dtr0 dtc1" data-priority="0">Champion (Men's or Unisex)</th><th class="dtr0 dtc2" data-priority="0">Hot Dogs</th><th class="dtr0 dtc3" data-priority="0">Champion (Women's)</th><th class="dtr0 dtc4" data-priority="0">Hot Dogs</th><th class="dtr0 dtc5" data-priority="0">Time<br/>
# (Minutes)</th><th class="dtr0 dtc6" data-priority="0">Eat Off</th><th class="dtr0 dtc7" data-priority="0">Date</th><th class="dtr0 dtc8" data-priority="0">Event</th></tr></thead><tbody><tr class="row1"><td class="dtr1 dtc0">2023</td><td class="dtr1 dtc1">Joey Chestnut</td><td class="dtr1 dtc2">62</td><td class="dtr1 dtc3">Miki Sudo</td><td class="dtr1 dtc4">39.5</td><td class="dtr1 dtc5">10</td><td class="dtr1 dtc6"></td><td class="dtr1 dtc7">7/4/2023</td><td class="dtr1 dtc8">Nathan's Hot Dog Eating Contest</td></tr><tr class="row2"><td class="dtr2 dtc0">2022</td><td class="dtr2 dtc1">Joey Chestnut</td><td class="dtr2 dtc2">63</td><td class="dtr2 dtc3">Miki Sudo</td><td class="dtr2 dtc4">40</td><td class="dtr2 dtc5">10</td><td class="dtr2 dtc6"></td><td class="dtr2 dtc7">7/4/2022</td><td class="dtr2 dtc8">Nathan's Hot Dog Eating Contest</td></tr><tr class="row3"><td class="dtr3 dtc0">2021</td><td class="dtr3 dtc1">Joey Chestnut</td><td class="dtr3 dtc2">76</td><td class="dtr3 dtc3">Michelle Lesco</td><td class="dtr3 dtc4">30.75</td><td class="dtr3 dtc5">10</td><td class="dtr3 dtc6"></td><td class="dtr3 dtc7">7/4/2021</td><td class="dtr3 dtc8">Nathan's Hot Dog Eating Contest</td></tr><tr class="row4"><td class="dtr4 dtc0">2020</td><td class="dtr4 dtc1">Joey Chestnut</td><td class="dtr4 dtc2">75</td><td class="dtr4 dtc3">Miki Sudo</td><td class="dtr4 dtc4">48.5</td><td class="dtr4 dtc5">10</td><td class="dtr4 dtc6"></td><td class="dtr4 dtc7">7/4/2020</td><td class="dtr4 dtc8">Nathan's Hot Dog Eating Contest</td></tr><tr class="row5"><td class="dtr5 dtc0">2019</td><td class="dtr5 dtc1">Joey Chestnut</td><td class="dtr5 dtc2">71</td><td class="dtr5 dtc3">Miki Sudo</td><td class="dtr5 dtc4">31</td><td class="dtr5 dtc5">10</td><td class="dtr5 dtc6"></td><td class="dtr5 dtc7">7/4/2019</td><td class="dtr5 dtc8">Nathan's Hot Dog Eating Contest</td></tr><tr class="row6"><td class="dtr6 dtc0">2018</td><td class="dtr6 dtc1">Joey Chestnut</td><td class="dtr6 dtc2">74</td><td class="dtr6 dtc3">Miki Sudo</td><td class="dtr6 dtc4">37</td><td class="dtr6 dtc5">10</td><td class="dtr6 dtc6"></td><td class="dtr6 dtc7">7/4/2018</td><td class="dtr6 dtc8">Nathan's Hot Dog Eating Contest</td></tr><tr class="row7"><td class="dtr7 dtc0">2017</td><td class="dtr7 dtc1">Joey Chestnut</td><td class="dtr7 dtc2">72</td><td class="dtr7 dtc3">Miki Sudo</td><td class="dtr7 dtc4">41</td><td class="dtr7 dtc5">10</td><td class="dtr7 dtc6"></td><td class="dtr7 dtc7">7/4/2017</td><td class="dtr7 dtc8">Nathan's Hot Dog Eating Contest</td></tr><tr class="row8"><td class="dtr8 dtc0">2016</td><td class="dtr8 dtc1">Joey Chestnut</td><td class="dtr8 dtc2">70</td><td class="dtr8 dtc3">Miki Sudo</td><td class="dtr8 dtc4">38.5</td><td class="dtr8 dtc5">10</td><td class="dtr8 dtc6"></td><td class="dtr8 dtc7">7/4/2016</td><td class="dtr8 dtc8">Nathan's Hot Dog Eating Contest</td></tr><tr class="row9"><td class="dtr9 dtc0">2015</td><td class="dtr9 dtc1">Matt Stonie</td><td class="dtr9 dtc2">62</td><td class="dtr9 dtc3">Miki Sudo</td><td class="dtr9 dtc4">38</td><td class="dtr9 dtc5">10</td><td class="dtr9 dtc6"></td><td class="dtr9 dtc7">7/4/2015</td><td class="dtr9 dtc8">Nathan's Hot Dog Eating Contest</td></tr><tr class="row10"><td class="dtr10 dtc0">2014</td><td class="dtr10 dtc1">Joey Chestnut</td><td class="dtr10 dtc2">61</td><td class="dtr10 dtc3">Miki Sudo</td><td class="dtr10 dtc4">34</td><td class="dtr10 dtc5">10</td><td class="dtr10 dtc6"></td><td class="dtr10 dtc7">7/4/2014</td><td class="dtr10 dtc8">Nathan's Hot Dog Eating Contest</td></tr><tr class="row11"><td class="dtr11 dtc0">2013</td><td class="dtr11 dtc1">Joey Chestnut</td><td class="dtr11 dtc2">69</td><td class="dtr11 dtc3">Sonya Thomas</td><td class="dtr11 dtc4">36.75</td><td class="dtr11 dtc5">10</td><td class="dtr11 dtc6"></td><td class="dtr11 dtc7">7/4/2013</td><td class="dtr11 dtc8">Nathan's Hot Dog Eating Contest</td></tr><tr class="row12"><td class="dtr12 dtc0">2012</td><td class="dtr12 dtc1">Joey Che ...

# %%
#Turned the table into a dataframe with pandas 
hot_table_df = pd.read_html("https://www.lastsandwich.com/articles/sandwich-sports/all-time-list-of-nathan-s-hot-dog-eating-champions") 
hot_table_df
# Out:
# [    Year       Champion (Men's or Unisex) Hot Dogs  \
#  0   2023                    Joey Chestnut       62
#  1   2022                    Joey Chestnut       63
#  2   2021                    Joey Chestnut       76
#  3   2020                    Joey Chestnut       75
#  4   2019                    Joey Chestnut       71
#  5   2018                    Joey Chestnut       74
#  6   2017                    Joey Chestnut       72
#  7   2016                    Joey Chestnut       70
#  8   2015                      Matt Stonie       62
#  9   2014                    Joey Chestnut       61
#  10  2013                    Joey Chestnut       69
#  11  2012                    Joey Chestnut       68
#  12  2011                    Joey Chestnut       62
#  13  2010                    Joey Chestnut       54
#  14  2009                    Joey Chestnut       68
#  15  2008                    Joey Chestnut       59
#  16  2007                    Joey Chestnut       66
#  17  2006                 Takeru Kobayashi    53.75
#  18  2005                 Takeru Kobayashi       49
#  19  2004                 Takeru Kobayashi     53.5
#  20  2003                 Takeru Kobayashi       44
#  21  2002                 Takeru Kobayashi     50.5
#  22  2001                 Takeru Kobayashi       50
#  23  2000                    Kazutoyo Arai       25
#  24  1999                     Steve Keiner     21.5
#  25  1998                Hirofumi Nakajima       19
#  26  1997                Hirofumi Nakajima     24.5
#  27  1996                Hirofumi Nakajima    23.25
#  28  1996                       Ed Krachie       22
#  29  1995                       Ed Krachie     19.5
#  30  1994                      Mike DeVito       20
#  31  1993                      Mike DeVito       17
#  32  1993                      Mike DeVito       18
#  33  1992                Frankie Dellarosa       19
#  34  1991                Frankie Dellarosa       21
#  35  1990            Mike DeVito/Jay Green       15
#  36  1989                        Jay Green     15.5
#  37  1988                        Jay Green       10
#  38  1987                      Don Wolfman     13.5
#  39  1986                      Mark Heller       15
#  40  1986                 Hiroaki Tominaga     10.5
#  41  1985                  Oscar Rodriguez       11
#  42  1984                    Birgit Felden      9.5
#  43  1983                       Emil Gomez     10.5
#  44  1982                    Steven Abrams       11
#  45  1981                   Thomas DeBerry       11
#  46  1980       Joe Baldini/Paul Siederman     9.75
#  47  1979       Luther Frazier/Jim Mattner       14
#  48  1978  Manel Hollenback/Kevin Sinclair       10
#  49  1975                     Lonnie Brown        8
#  50  1974           Walter Paul/Paul Sirop        -
#  51  1974                   Roberto Muriel       10
#  52  1974                    John Connolly        9
#  53  1973                        (Unknown)        -
#  54  1973                      (Cancelled)        -
#  55  1972                  Melody Andorfer       12
#  56  1972                  Jason Schechter       14
#  57  1967                      Walter Paul      127
#
#                  Champion (Women's)  Hot Dogs.1 Time (Minutes) Eat Off  \
#  0                        Miki Sudo       39.50             10     NaN
#  1                        Miki Sudo       40.00             10     NaN
#  2                   Michelle Lesco       30.75             10     NaN
#  3                        Miki Sudo       48.50             10     NaN
#  4                        Miki Sudo       31.00             10     NaN
#  5                        Miki Sudo       37.00             10     NaN
#  6                        Miki Sudo       41.00             10     NaN
#  7                        Miki Sudo       38.50             10     NaN
#  8                        Miki Sudo       38.00             10     NaN
#  9                        Miki Sudo       34.00             10     NaN
#  10                    Sonya Thomas       36.75             10     NaN
#  11                    Sonya Thomas       45.00             10     NaN
#  12                    Sonya Thomas       40.00             10     NaN
#  13                    Unisex Event         NaN             10     NaN
#  14                    Unisex Event         NaN             10     NaN
#  15                    Unisex Event         NaN             10       X
#  16                    Unisex Event         NaN             12     NaN
#  17                    Unisex Event         NaN             12     NaN
#  18                    Unisex Event         NaN             12     NaN
#  19                    Unisex Event         NaN             12     NaN
#  20                    Unisex Event         NaN             12     NaN
#  21                    Unisex Event         NaN             12     NaN
#  22                    Unisex Event         NaN             12     NaN
#  23                    Unisex Event         NaN             12     NaN
#  24                    Unisex Event         NaN             12     NaN
#  25                    Unisex Event         NaN             12     NaN
#  26                    Unisex Event         NaN             12     NaN
#  27                    Unisex Event         NaN             12     NaN
#  28                    Unisex Event         NaN             12     NaN
#  29                    Unisex Event         NaN             12     NaN
#  30                    Unisex Event         NaN             12     NaN
#  31                    Unisex Event         NaN             12     NaN
#  32                    Unisex Event         NaN             12     NaN
#  33                    Unisex Event         NaN             12     NaN
#  34                    Unisex Event         NaN             12     NaN
#  35                    Unisex Event         NaN             12     NaN
#  36                    Unisex Event         NaN             12     NaN
#  37                    Unisex Event         NaN             12     NaN
#  38                    Unisex Event         NaN             10     NaN
#  39                    Unisex Event         NaN             10     NaN
#  40                    Unisex Event         NaN             10     NaN
#  41                    Unisex Event         NaN             12     NaN
#  42    Birgit Felden (Unisex Event)        9.50             10     NaN
#  43                    Unisex Event         NaN             10     NaN
#  44                    Unisex Event         NaN             10     NaN
#  45                    Unisex Event         NaN              5     NaN
#  46                    Unisex Event         NaN             10       X
#  47                    Unisex Event         NaN             10       X
#  48                    Unisex Event         NaN            6.5     NaN
#  49                  Sharlene Smith        8.50            3.5     NaN
#  50                    Unisex Event         NaN              -     NaN
#  51                    Unisex Event         NaN            3.5     NaN
#  52                    Unisex Event         NaN            2.5     NaN
#  53                    Unisex Event         NaN              -     NaN
#  54                    Unisex Event         NaN              -     NaN
#  55  Melody Andorfer (Unisex Event）       12.00              5     NaN
#  56                    Unisex Event         NaN            3.5     NaN
#  57                    Unisex Event         NaN             60     NaN
#
#              Date                            Event
#  0       7/4/2023  Nathan's Hot Dog Eating Contest
#  1       7/4/2022  Nathan's Hot Dog Eating Contest
#  2       7/4/2021  Nathan's Hot Dog Eating Contest
#  3       7/4/2020  Nathan's Hot Dog Eating Contest
#  4       7/4/2019  Nathan's Hot Dog Eating Contest
#  5       7/4/2018  Nathan's Hot Dog Eating Contest
#  6       7/4/2017  Nathan's Hot Dog Eating Contest
#  7       7/4/2016  Nathan's Hot Dog Eating Contest
#  8       7/4/2015  Nathan's Hot Dog Eating Contest
#  9       7/4/2014  Nathan's Hot Dog Eating Contest
#  10      7/4/2013  Nathan's Hot Dog Eating Contest
#  11      7/4/2012  Nathan's Hot Dog Eating Contest
#  12      7/4/2011  Nathan's Hot Dog Eating Contest
#  13      7/4/2010  Nathan's Hot Dog Eating Contest
#  14      7/4/2009  Nathan's Hot Dog Eating Contest
#  15      7/4/2008  Nathan's Hot Dog Eating Contest
#  16      7/4/2007  Nathan's Hot Dog Eating Contest
#  17      7/4/2006  Nathan's Hot Dog Eating Contest
#  18      7/4/2005  Nathan's Hot Dog Eating Contest
#  19      7/4/2004  Nathan's Hot Dog Eating Contest
#  20      7/4/2003  Nathan's Hot Dog Eating Contest
#  21      7/4/2002  Nathan's Hot Dog Eating Contest
#  22      7/4/2001  Nathan's Hot Dog Eating Contest
#  23      7/4/2000  Nathan's Hot Dog Eating Contest
#  24      7/4/1999  Nathan's Hot Dog Eating Contest
#  25      7/4/1998  Nathan's Hot Dog Eating Contest
#  26      7/4/1997  Nathan's Hot Dog Eating Contest
#  27     12/4/1996  One-On-One Challenge With Japan
#  28      7/4/1996  Nathan's Hot Dog Eating Contest
#  29      7/4/1995  Nathan's Hot Dog Eating Contest
#  30      7/4/1994  Nathan's Hot Dog Eating Contest
#  31      7/4/1993  Nathan's Hot Dog Eating Contest
#  32    10/27/1993  One-On-One Challenge With Japan
#  33      7/4/1992  Nathan's Hot Dog Eating Contest
#  34      7/4/1991  Nathan's Hot Dog Eating Contest
#  35      7/4/1990  Nathan's Hot Dog Eating Contest
#  36      7/4/1989  Nathan's Hot Dog Eating Contest
#  37      7/4/1988  Nathan's Hot Dog Eating Contest
#  38      7/4/1987  Nathan's Hot Dog Eating Contest
#  39      7/4/1986  Nathan's Hot Dog Eating Contest
#  40     2/11/1986  One-On-One Challenge With Japan
#  41      7/4/1985  Nathan's Hot Dog Eating Contest
#  42      7/4/1984  Nathan's Hot Dog Eating Contest
#  43      7/4/1983  Nathan's Hot Dog Eating Contest
#  44      7/5/1982  Nathan's Hot Dog Eating Contest
#  45      7/4/1981  Nathan's Hot Dog Eating Contest
#  46      7/4/1980  Nathan's Hot Dog Eating Contest
#  47      7/4/1979  Nathan's Hot Dog Eating Contest
#  48  Memorial Day  Nathan's Hot Dog Eating Contest
#  49  Memorial Day  Nathan's Hot Dog Eating Contest
#  50     Labor Day  Nathan's Hot Dog Eating Contest
#  51      7/4/1974  Nathan's Hot Dog Eating Contest
#  52      4/7/1974  Nathan's Hot Dog Eating Contest
#  53      7/4/1973  Nathan's Hot Dog Eating Contest
#  54      4/7/1973  Nathan's Hot Dog Eating Contest
#  55     Labor Day  Nathan's Hot Dog Eating Contest
#  56  Memorial Day  Nathan's Hot Dog Eating Contest
#  57     6/30/1967  Nathan's Hot Dog Eating Contest  ]

# %%
hot_table_dfs = pd.read_html('https://www.lastsandwich.com/articles/sandwich-sports/all-time-list-of-nathan-s-hot-dog-eating-champions')

# pandas.read_html() returns a list of DataFrames. Specify the index to select the desired table, even if it's the only one.
hot_table_df = hot_table_dfs[0]
hot_table_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        58 non-null     int64
#  1   Champion (Men's or Unisex)  58 non-null     object
#  2   Hot Dogs                    58 non-null     object
#  3   Champion (Women's)          58 non-null     object
#  4   Hot Dogs.1                  16 non-null     float64
#  5   Time (Minutes)              58 non-null     object
#  6   Eat Off                     3 non-null      object
#  7   Date                        58 non-null     object
#  8   Event                       58 non-null     object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 4.2+ KB

# %%
#Removed unwanted columns 
table = hot_table_df.drop(columns = ["Event", "Date", "Eat Off", "Time (Minutes)" ])
table
# Out:
#     Year       Champion (Men's or Unisex) Hot Dogs  \
# 0   2023                    Joey Chestnut       62
# 1   2022                    Joey Chestnut       63
# 2   2021                    Joey Chestnut       76
# 3   2020                    Joey Chestnut       75
# 4   2019                    Joey Chestnut       71
# 5   2018                    Joey Chestnut       74
# 6   2017                    Joey Chestnut       72
# 7   2016                    Joey Chestnut       70
# 8   2015                      Matt Stonie       62
# 9   2014                    Joey Chestnut       61
# 10  2013                    Joey Chestnut       69
# 11  2012                    Joey Chestnut       68
# 12  2011                    Joey Chestnut       62
# 13  2010                    Joey Chestnut       54
# 14  2009                    Joey Chestnut       68
# 15  2008                    Joey Chestnut       59
# 16  2007                    Joey Chestnut       66
# 17  2006                 Takeru Kobayashi    53.75
# 18  2005                 Takeru Kobayashi       49
# 19  2004                 Takeru Kobayashi     53.5
# 20  2003                 Takeru Kobayashi       44
# 21  2002                 Takeru Kobayashi     50.5
# 22  2001                 Takeru Kobayashi       50
# 23  2000                    Kazutoyo Arai       25
# 24  1999                     Steve Keiner     21.5
# 25  1998                Hirofumi Nakajima       19
# 26  1997                Hirofumi Nakajima     24.5
# 27  1996                Hirofumi Nakajima    23.25
# 28  1996                       Ed Krachie       22
# 29  1995                       Ed Krachie     19.5
# 30  1994                      Mike DeVito       20
# 31  1993                      Mike DeVito       17
# 32  1993                      Mike DeVito       18
# 33  1992                Frankie Dellarosa       19
# 34  1991                Frankie Dellarosa       21
# 35  1990            Mike DeVito/Jay Green       15
# 36  1989                        Jay Green     15.5
# 37  1988                        Jay Green       10
# 38  1987                      Don Wolfman     13.5
# 39  1986                      Mark Heller       15
# 40  1986                 Hiroaki Tominaga     10.5
# 41  1985                  Oscar Rodriguez       11
# 42  1984                    Birgit Felden      9.5
# 43  1983                       Emil Gomez     10.5
# 44  1982                    Steven Abrams       11
# 45  1981                   Thomas DeBerry       11
# 46  1980       Joe Baldini/Paul Siederman     9.75
# 47  1979       Luther Frazier/Jim Mattner       14
# 48  1978  Manel Hollenback/Kevin Sinclair       10
# 49  1975                     Lonnie Brown        8
# 50  1974           Walter Paul/Paul Sirop        -
# 51  1974                   Roberto Muriel       10
# 52  1974                    John Connolly        9
# 53  1973                        (Unknown)        -
# 54  1973                      (Cancelled)        -
# 55  1972                  Melody Andorfer       12
# 56  1972                  Jason Schechter       14
# 57  1967                      Walter Paul      127
#
#                 Champion (Women's)  Hot Dogs.1
# 0                        Miki Sudo       39.50
# 1                        Miki Sudo       40.00
# 2                   Michelle Lesco       30.75
# 3                        Miki Sudo       48.50
# 4                        Miki Sudo       31.00
# 5                        Miki Sudo       37.00
# 6                        Miki Sudo       41.00
# 7                        Miki Sudo       38.50
# 8                        Miki Sudo       38.00
# 9                        Miki Sudo       34.00
# 10                    Sonya Thomas       36.75
# 11                    Sonya Thomas       45.00
# 12                    Sonya Thomas       40.00
# 13                    Unisex Event         NaN
# 14                    Unisex Event         NaN
# 15                    Unisex Event         NaN
# 16                    Unisex Event         NaN
# 17                    Unisex Event         NaN
# 18                    Unisex Event         NaN
# 19                    Unisex Event         NaN
# 20                    Unisex Event         NaN
# 21                    Unisex Event         NaN
# 22                    Unisex Event         NaN
# 23                    Unisex Event         NaN
# 24                    Unisex Event         NaN
# 25                    Unisex Event         NaN
# 26                    Unisex Event         NaN
# 27                    Unisex Event         NaN
# 28                    Unisex Event         NaN
# 29                    Unisex Event         NaN
# 30                    Unisex Event         NaN
# 31                    Unisex Event         NaN
# 32                    Unisex Event         NaN
# 33                    Unisex Event         NaN
# 34                    Unisex Event         NaN
# 35                    Unisex Event         NaN
# 36                    Unisex Event         NaN
# 37                    Unisex Event         NaN
# 38                    Unisex Event         NaN
# 39                    Unisex Event         NaN
# 40                    Unisex Event         NaN
# 41                    Unisex Event         NaN
# 42    Birgit Felden (Unisex Event)        9.50
# 43                    Unisex Event         NaN
# 44                    Unisex Event         NaN
# 45                    Unisex Event         NaN
# 46                    Unisex Event         NaN
# 47                    Unisex Event         NaN
# 48                    Unisex Event         NaN
# 49                  Sharlene Smith        8.50
# 50                    Unisex Event         NaN
# 51                    Unisex Event         NaN
# 52                    Unisex Event         NaN
# 53                    Unisex Event         NaN
# 54                    Unisex Event         NaN
# 55  Melody Andorfer (Unisex Event）       12.00
# 56                    Unisex Event         NaN
# 57                    Unisex Event         NaN

# %%
#Most Hotdogs Ate by Woman 
max(table["Hot Dogs.1"])
# Out:
# 48.5

# %%
#Most Hotdogs are by men or unisex (Not working for some reason)
max(table["Hot Dogs"])
# Out:
# '9.75'

# %%
#Renamed the Column by calling it by column because referencing it by it's original title was not working 
r_table.rename(columns={r_table.columns[1]: 'Mens',r_table.columns[3]:'Womans'})
# Out:
#     Year                             Mens Hot Dogs  \
# 0   2023                    Joey Chestnut       62
# 1   2022                    Joey Chestnut       63
# 2   2021                    Joey Chestnut       76
# 3   2020                    Joey Chestnut       75
# 4   2019                    Joey Chestnut       71
# 5   2018                    Joey Chestnut       74
# 6   2017                    Joey Chestnut       72
# 7   2016                    Joey Chestnut       70
# 8   2015                      Matt Stonie       62
# 9   2014                    Joey Chestnut       61
# 10  2013                    Joey Chestnut       69
# 11  2012                    Joey Chestnut       68
# 12  2011                    Joey Chestnut       62
# 13  2010                    Joey Chestnut       54
# 14  2009                    Joey Chestnut       68
# 15  2008                    Joey Chestnut       59
# 16  2007                    Joey Chestnut       66
# 17  2006                 Takeru Kobayashi    53.75
# 18  2005                 Takeru Kobayashi       49
# 19  2004                 Takeru Kobayashi     53.5
# 20  2003                 Takeru Kobayashi       44
# 21  2002                 Takeru Kobayashi     50.5
# 22  2001                 Takeru Kobayashi       50
# 23  2000                    Kazutoyo Arai       25
# 24  1999                     Steve Keiner     21.5
# 25  1998                Hirofumi Nakajima       19
# 26  1997                Hirofumi Nakajima     24.5
# 27  1996                Hirofumi Nakajima    23.25
# 28  1996                       Ed Krachie       22
# 29  1995                       Ed Krachie     19.5
# 30  1994                      Mike DeVito       20
# 31  1993                      Mike DeVito       17
# 32  1993                      Mike DeVito       18
# 33  1992                Frankie Dellarosa       19
# 34  1991                Frankie Dellarosa       21
# 35  1990            Mike DeVito/Jay Green       15
# 36  1989                        Jay Green     15.5
# 37  1988                        Jay Green       10
# 38  1987                      Don Wolfman     13.5
# 39  1986                      Mark Heller       15
# 40  1986                 Hiroaki Tominaga     10.5
# 41  1985                  Oscar Rodriguez       11
# 42  1984                    Birgit Felden      9.5
# 43  1983                       Emil Gomez     10.5
# 44  1982                    Steven Abrams       11
# 45  1981                   Thomas DeBerry       11
# 46  1980       Joe Baldini/Paul Siederman     9.75
# 47  1979       Luther Frazier/Jim Mattner       14
# 48  1978  Manel Hollenback/Kevin Sinclair       10
# 49  1975                     Lonnie Brown        8
# 51  1974                   Roberto Muriel       10
# 52  1974                    John Connolly        9
# 55  1972                  Melody Andorfer       12
# 56  1972                  Jason Schechter       14
# 57  1967                      Walter Paul      127
#
#                             Womans  Hot Dogs.1
# 0                        Miki Sudo       39.50
# 1                        Miki Sudo       40.00
# 2                   Michelle Lesco       30.75
# 3                        Miki Sudo       48.50
# 4                        Miki Sudo       31.00
# 5                        Miki Sudo       37.00
# 6                        Miki Sudo       41.00
# 7                        Miki Sudo       38.50
# 8                        Miki Sudo       38.00
# 9                        Miki Sudo       34.00
# 10                    Sonya Thomas       36.75
# 11                    Sonya Thomas       45.00
# 12                    Sonya Thomas       40.00
# 13                    Unisex Event         NaN
# 14                    Unisex Event         NaN
# 15                    Unisex Event         NaN
# 16                    Unisex Event         NaN
# 17                    Unisex Event         NaN
# 18                    Unisex Event         NaN
# 19                    Unisex Event         NaN
# 20                    Unisex Event         NaN
# 21                    Unisex Event         NaN
# 22                    Unisex Event         NaN
# 23                    Unisex Event         NaN
# 24                    Unisex Event         NaN
# 25                    Unisex Event         NaN
# 26                    Unisex Event         NaN
# 27                    Unisex Event         NaN
# 28                    Unisex Event         NaN
# 29                    Unisex Event         NaN
# 30                    Unisex Event         NaN
# 31                    Unisex Event         NaN
# 32                    Unisex Event         NaN
# 33                    Unisex Event         NaN
# 34                    Unisex Event         NaN
# 35                    Unisex Event         NaN
# 36                    Unisex Event         NaN
# 37                    Unisex Event         NaN
# 38                    Unisex Event         NaN
# 39                    Unisex Event         NaN
# 40                    Unisex Event         NaN
# 41                    Unisex Event         NaN
# 42    Birgit Felden (Unisex Event)        9.50
# 43                    Unisex Event         NaN
# 44                    Unisex Event         NaN
# 45                    Unisex Event         NaN
# 46                    Unisex Event         NaN
# 47                    Unisex Event         NaN
# 48                    Unisex Event         NaN
# 49                  Sharlene Smith        8.50
# 51                    Unisex Event         NaN
# 52                    Unisex Event         NaN
# 55  Melody Andorfer (Unisex Event）       12.00
# 56                    Unisex Event         NaN
# 57                    Unisex Event         NaN

# %%
r_table1 = r_table.rename(columns={r_table.columns[1]: 'Mens',r_table.columns[3]:'Womans'})
r_table1
# Out:
#     Year                             Mens Hot Dogs  \
# 0   2023                    Joey Chestnut       62
# 1   2022                    Joey Chestnut       63
# 2   2021                    Joey Chestnut       76
# 3   2020                    Joey Chestnut       75
# 4   2019                    Joey Chestnut       71
# 5   2018                    Joey Chestnut       74
# 6   2017                    Joey Chestnut       72
# 7   2016                    Joey Chestnut       70
# 8   2015                      Matt Stonie       62
# 9   2014                    Joey Chestnut       61
# 10  2013                    Joey Chestnut       69
# 11  2012                    Joey Chestnut       68
# 12  2011                    Joey Chestnut       62
# 13  2010                    Joey Chestnut       54
# 14  2009                    Joey Chestnut       68
# 15  2008                    Joey Chestnut       59
# 16  2007                    Joey Chestnut       66
# 17  2006                 Takeru Kobayashi    53.75
# 18  2005                 Takeru Kobayashi       49
# 19  2004                 Takeru Kobayashi     53.5
# 20  2003                 Takeru Kobayashi       44
# 21  2002                 Takeru Kobayashi     50.5
# 22  2001                 Takeru Kobayashi       50
# 23  2000                    Kazutoyo Arai       25
# 24  1999                     Steve Keiner     21.5
# 25  1998                Hirofumi Nakajima       19
# 26  1997                Hirofumi Nakajima     24.5
# 27  1996                Hirofumi Nakajima    23.25
# 28  1996                       Ed Krachie       22
# 29  1995                       Ed Krachie     19.5
# 30  1994                      Mike DeVito       20
# 31  1993                      Mike DeVito       17
# 32  1993                      Mike DeVito       18
# 33  1992                Frankie Dellarosa       19
# 34  1991                Frankie Dellarosa       21
# 35  1990            Mike DeVito/Jay Green       15
# 36  1989                        Jay Green     15.5
# 37  1988                        Jay Green       10
# 38  1987                      Don Wolfman     13.5
# 39  1986                      Mark Heller       15
# 40  1986                 Hiroaki Tominaga     10.5
# 41  1985                  Oscar Rodriguez       11
# 42  1984                    Birgit Felden      9.5
# 43  1983                       Emil Gomez     10.5
# 44  1982                    Steven Abrams       11
# 45  1981                   Thomas DeBerry       11
# 46  1980       Joe Baldini/Paul Siederman     9.75
# 47  1979       Luther Frazier/Jim Mattner       14
# 48  1978  Manel Hollenback/Kevin Sinclair       10
# 49  1975                     Lonnie Brown        8
# 51  1974                   Roberto Muriel       10
# 52  1974                    John Connolly        9
# 55  1972                  Melody Andorfer       12
# 56  1972                  Jason Schechter       14
# 57  1967                      Walter Paul      127
#
#                             Womans  Hot Dogs.1
# 0                        Miki Sudo       39.50
# 1                        Miki Sudo       40.00
# 2                   Michelle Lesco       30.75
# 3                        Miki Sudo       48.50
# 4                        Miki Sudo       31.00
# 5                        Miki Sudo       37.00
# 6                        Miki Sudo       41.00
# 7                        Miki Sudo       38.50
# 8                        Miki Sudo       38.00
# 9                        Miki Sudo       34.00
# 10                    Sonya Thomas       36.75
# 11                    Sonya Thomas       45.00
# 12                    Sonya Thomas       40.00
# 13                    Unisex Event         NaN
# 14                    Unisex Event         NaN
# 15                    Unisex Event         NaN
# 16                    Unisex Event         NaN
# 17                    Unisex Event         NaN
# 18                    Unisex Event         NaN
# 19                    Unisex Event         NaN
# 20                    Unisex Event         NaN
# 21                    Unisex Event         NaN
# 22                    Unisex Event         NaN
# 23                    Unisex Event         NaN
# 24                    Unisex Event         NaN
# 25                    Unisex Event         NaN
# 26                    Unisex Event         NaN
# 27                    Unisex Event         NaN
# 28                    Unisex Event         NaN
# 29                    Unisex Event         NaN
# 30                    Unisex Event         NaN
# 31                    Unisex Event         NaN
# 32                    Unisex Event         NaN
# 33                    Unisex Event         NaN
# 34                    Unisex Event         NaN
# 35                    Unisex Event         NaN
# 36                    Unisex Event         NaN
# 37                    Unisex Event         NaN
# 38                    Unisex Event         NaN
# 39                    Unisex Event         NaN
# 40                    Unisex Event         NaN
# 41                    Unisex Event         NaN
# 42    Birgit Felden (Unisex Event)        9.50
# 43                    Unisex Event         NaN
# 44                    Unisex Event         NaN
# 45                    Unisex Event         NaN
# 46                    Unisex Event         NaN
# 47                    Unisex Event         NaN
# 48                    Unisex Event         NaN
# 49                  Sharlene Smith        8.50
# 51                    Unisex Event         NaN
# 52                    Unisex Event         NaN
# 55  Melody Andorfer (Unisex Event）       12.00
# 56                    Unisex Event         NaN
# 57                    Unisex Event         NaN

# %%
#All the times Joey Chestnut won 
jc=r_table1.loc[r_table1['Mens'] == "Joey Chestnut"]
jc
# Out:
#     Year           Mens Hot Dogs          Womans  Hot Dogs.1
# 0   2023  Joey Chestnut       62       Miki Sudo       39.50
# 1   2022  Joey Chestnut       63       Miki Sudo       40.00
# 2   2021  Joey Chestnut       76  Michelle Lesco       30.75
# 3   2020  Joey Chestnut       75       Miki Sudo       48.50
# 4   2019  Joey Chestnut       71       Miki Sudo       31.00
# 5   2018  Joey Chestnut       74       Miki Sudo       37.00
# 6   2017  Joey Chestnut       72       Miki Sudo       41.00
# 7   2016  Joey Chestnut       70       Miki Sudo       38.50
# 9   2014  Joey Chestnut       61       Miki Sudo       34.00
# 10  2013  Joey Chestnut       69    Sonya Thomas       36.75
# 11  2012  Joey Chestnut       68    Sonya Thomas       45.00
# 12  2011  Joey Chestnut       62    Sonya Thomas       40.00
# 13  2010  Joey Chestnut       54    Unisex Event         NaN
# 14  2009  Joey Chestnut       68    Unisex Event         NaN
# 15  2008  Joey Chestnut       59    Unisex Event         NaN
# 16  2007  Joey Chestnut       66    Unisex Event         NaN

# %%
tk=r_table1.loc[r_table1['Mens'] == "Takeru Kobayashi"]
tk
# Out:
#     Year              Mens Hot Dogs        Womans  Hot Dogs.1
# 17  2006  Takeru Kobayashi    53.75  Unisex Event         NaN
# 18  2005  Takeru Kobayashi       49  Unisex Event         NaN
# 19  2004  Takeru Kobayashi     53.5  Unisex Event         NaN
# 20  2003  Takeru Kobayashi       44  Unisex Event         NaN
# 21  2002  Takeru Kobayashi     50.5  Unisex Event         NaN
# 22  2001  Takeru Kobayashi       50  Unisex Event         NaN

# %%
ms = tk=r_table1.loc[r_table1['Womans'] == "Miki Sudo"]
ms
# Out:
#    Year           Mens Hot Dogs     Womans  Hot Dogs.1
# 0  2023  Joey Chestnut       62  Miki Sudo        39.5
# 1  2022  Joey Chestnut       63  Miki Sudo        40.0
# 3  2020  Joey Chestnut       75  Miki Sudo        48.5
# 4  2019  Joey Chestnut       71  Miki Sudo        31.0
# 5  2018  Joey Chestnut       74  Miki Sudo        37.0
# 6  2017  Joey Chestnut       72  Miki Sudo        41.0
# 7  2016  Joey Chestnut       70  Miki Sudo        38.5
# 8  2015    Matt Stonie       62  Miki Sudo        38.0
# 9  2014  Joey Chestnut       61  Miki Sudo        34.0

# %%
#Total number of Hot dogs ate by JC
62+63+76+75+71+74+72+70+61+69+68+62+54+68+59+66
# Out:
# 1070

# %%
#Total number of hot dogs ate by tk
53.75+49+53.5+44+50.5+50
# Out:
# 300.75

# %%
#Total number of hot dogs ate by ms
38.5+40+48.5+31.0+37+41+38.5+38+34
# Out:
# 346.5
